# %% [markdown]
# # Movie Recommendation
# By Reagan Orth

# %%
import ast
from collections import Counter
import itertools
import json
import numpy as np
import pandas as pd
import re
import string
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch_geometric
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader, LinkNeighborLoader
from torch_geometric.nn import GCNConv, SAGEConv
import torch_geometric.transforms as T

# %% [markdown]
# ## Movie Dataset Cleaning

# %%
# Next get the Movie dataset
movies_df = pd.read_csv("Top1000.csv")
movies_df.drop(columns=["Unnamed: 0", "votes"], inplace=True)  # Remove external indexing column
movies_df.iloc[:10]
# Out:
#                                                title    year certificate  \
# 0               1.\nThe Shawshank Redemption\n(1994)  (1994)           R
# 1                          2.\nThe Godfather\n(1972)  (1972)           R
# 2                        3.\nThe Dark Knight\n(2008)  (2008)       PG-13
# 3                       4.\nSchindler's List\n(1993)  (1993)           R
# 4  5.\nThe Lord of the Rings: The Return of the K...  (2003)       PG-13
# 5                           6.\n12 Angry Men\n(1957)  (1957)    Approved
# 6                  7.\nThe Godfather Part II\n(1974)  (1974)           R
# 7                           8.\nPulp Fiction\n(1994)  (1994)           R
# 8                              9.\nInception\n(2010)  (2010)       PG-13
# 9  10.\nThe Lord of the Rings: The Fellowship of ...  (2001)       PG-13
#
#       time                      genre  rating                       metascore  \
# 0  142 min                      Drama     9.3   82        \n        Metascore
# 1  175 min               Crime, Drama     9.2  100        \n        Metascore
# 2  152 min       Action, Crime, Drama     9.0   84        \n        Metascore
# 3  195 min  Biography, Drama, History     9.0   95        \n        Metascore
# 4  201 min   Action, Adventure, Drama     9.0   94        \n        Metascore
# 5   96 min               Crime, Drama     9.0   97        \n        Metascore
# 6  202 min               Crime, Drama     9.0   90        \n        Metascore
# 7  154 min               Crime, Drama     8.9   95        \n        Metascore
# 8  148 min  Action, Adventure, Sci-Fi     8.8   74        \n        Metascore
# 9  178 min   Action, Adventure, Drama     8.8   92        \n        Metascore
#
#                                          simple_desc             directors  \
# 0  Over the course of several years, two convicts...        Frank Darabont
# 1  The aging patriarch of an organized crime dyna...  Francis Ford Coppola
# 2  When the menace known as the Joker wreaks havo...     Christopher Nolan
# 3  In German-occupied Poland during World War II,...       Oskar Schindler
# 4  Gandalf and Aragorn lead the World of Men agai...         Peter Jackson
# 5  The jury in a New York City murder trial is fr...          Sidney Lumet
# 6  The early life and career of Vito Corleone in ...  Francis Ford Coppola
# 7  The lives of two mob hitmen, a boxer, a gangst...     Quentin Tarantino
# 8  A thief who steals corporate secrets through t...     Christopher Nolan
# 9  A meek Hobbit from the Shire and eight compani...         Peter Jackson
#
#                                               actors
# 0  ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'...
# 1  ['Marlon Brando', 'Al Pacino', 'James Caan', '...
# 2  ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 3  ['Steven Spielberg', 'Liam Neeson', 'Ralph Fie...
# 4  ['Elijah Wood', 'Viggo Mortensen', 'Ian McKell...
# 5  ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'...
# 6  ['Al Pacino', 'Robert De Niro', 'Robert Duvall...
# 7  ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# 8  ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', ...
# 9  ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom...

# %%
# Clean up formatting within columns
movies_df["title"] = [i.split("\n")[1] for i in movies_df["title"]]
movies_df["year"] = [re.match(".*\([0-9]*\)", i)[0][1:-1][-4:] for i in movies_df["year"]]
movies_df["year"] = movies_df["year"].astype(int)
movies_df["decade"] = movies_df["year"] // 10 * 10
movies_df["time"] = [int(i[:i.index(" ")]) for i in movies_df["time"]]
movies_df["genre"] = movies_df["genre"].str.split(", ")
movies_df["metascore"] = [int(i[:i.index(" ")]) for i in movies_df["metascore"]]
movies_df["directors"] = movies_df["directors"].str.split(", ")
movies_df["actors"] = movies_df["actors"].apply(ast.literal_eval)
movies_df.drop_duplicates(subset=["title"], inplace=True)
movies_df.index = [i for i in range(len(movies_df))]
movies_df.iloc[:10]
# Out:
#                                                title  year certificate  time  \
# 0                           The Shawshank Redemption  1994           R   142
# 1                                      The Godfather  1972           R   175
# 2                                    The Dark Knight  2008       PG-13   152
# 3                                   Schindler's List  1993           R   195
# 4      The Lord of the Rings: The Return of the King  2003       PG-13   201
# 5                                       12 Angry Men  1957    Approved    96
# 6                              The Godfather Part II  1974           R   202
# 7                                       Pulp Fiction  1994           R   154
# 8                                          Inception  2010       PG-13   148
# 9  The Lord of the Rings: The Fellowship of the Ring  2001       PG-13   178
#
#                          genre  rating  metascore  \
# 0                      [Drama]     9.3         82
# 1               [Crime, Drama]     9.2        100
# 2       [Action, Crime, Drama]     9.0         84
# 3  [Biography, Drama, History]     9.0         95
# 4   [Action, Adventure, Drama]     9.0         94
# 5               [Crime, Drama]     9.0         97
# 6               [Crime, Drama]     9.0         90
# 7               [Crime, Drama]     8.9         95
# 8  [Action, Adventure, Sci-Fi]     8.8         74
# 9   [Action, Adventure, Drama]     8.8         92
#
#                                          simple_desc               directors  \
# 0  Over the course of several years, two convicts...        [Frank Darabont]
# 1  The aging patriarch of an organized crime dyna...  [Francis Ford Coppola]
# 2  When the menace known as the Joker wreaks havo...     [Christopher Nolan]
# 3  In German-occupied Poland during World War II,...       [Oskar Schindler]
# 4  Gandalf and Aragorn lead the World of Men agai...         [Peter Jackson]
# 5  The jury in a New York City murder trial is fr...          [Sidney Lumet]
# 6  The early life and career of Vito Corleone in ...  [Francis Ford Coppola]
# 7  The lives of two mob hitmen, a boxer, a gangst...     [Quentin Tarantino]
# 8  A thief who steals corporate secrets through t...     [Christopher Nolan]
# 9  A meek Hobbit from the Shire and eight compani...         [Peter Jackson]
#
#                                               actors  decade
# 0  [Tim Robbins, Morgan Freeman, Bob Gunton, Will...    1990
# 1  [Marlon Brando, Al Pacino, James Caan, Diane K...    1970
# 2  [Christian Bale, Heath Ledger, Aaron Eckhart, ...    2000
# 3  [Steven Spielberg, Liam Neeson, Ralph Fiennes,...    1990
# 4  [Elijah Wood, Viggo Mortensen, Ian McKellen, O...    2000
# 5  [Henry Fonda, Lee J. Cobb, Martin Balsam, John...    1950
# 6  [Al Pacino, Robert De Niro, Robert Duvall, Dia...    1970
# 7  [John Travolta, Uma Thurman, Samuel L. Jackson...    1990
# 8  [Leonardo DiCaprio, Joseph Gordon-Levitt, Elli...    2010
# 9  [Elijah Wood, Ian McKellen, Orlando Bloom, Sea...    2000

# %% [markdown]
# ## Naive Recommender System

# %%
# First generate a very simple recommendation system based on a score system, for comparison

naive_edges = np.zeros((len(movies_df), len(movies_df)))
for i, film1 in enumerate(movies_df.itertuples()):
    for j, film2 in enumerate(movies_df.itertuples()):
        if i == j:
            continue
            
        score = 0
        for genre in film1[5]:  # 5 indicates the Genre list
            if genre in film2[5]:
                score += 1
        for director in film1[9]:  # 9 is the Directors index
            if director in film2[9]:
                score += 1
        for actor in film1[10]:  # 10 is the Actors index
            if actor in film2[10]:
                score += 1
        
        naive_edges[i, j] = score
        
# Generate similarities DataFrame
similarities = pd.DataFrame(naive_edges, columns=list(movies_df["title"]), index=list(movies_df["title"]))
most_similar_naive = pd.DataFrame([movies_df["title"][similarities[film].argmax()] for film in movies_df["title"]], index=movies_df["title"], columns=["Most Similar Film"])
with pd.option_context('display.max_colwidth', None, 'display.max_rows', 250):
    display(similarities.iloc[:10, :10])
# Out:
#                                                    The Shawshank Redemption  \
# The Shawshank Redemption                                                0.0
# The Godfather                                                           1.0
# The Dark Knight                                                         1.0
# Schindler's List                                                        1.0
# The Lord of the Rings: The Return of the King                           1.0
# 12 Angry Men                                                            1.0
# The Godfather Part II                                                   1.0
# Pulp Fiction                                                            1.0
# Inception                                                               0.0
# The Lord of the Rings: The Fellowship of the Ring                       1.0
#
#                                                    The Godfather  \
# The Shawshank Redemption                                     1.0
# The Godfather                                                0.0
# The Dark Knight                                              2.0
# Schindler's List                                             1.0
# The Lord of the Rings: The Return of the King                1.0
# 12 Angry Men                                                 2.0
# The Godfather Part II                                        5.0
# Pulp Fiction                                                 2.0
# Inception                                                    0.0
# The Lord of the Rings: The Fellowship of the Ring            1.0
#
#                                                    The Dark Knight  \
# The Shawshank Redemption                                       1.0
# The Godfather                                                  2.0
# The Dark Knight                                                0.0
# Schindler's List                                               1.0
# The Lord of the Rings: The Return of the King                  2.0
# 12 Angry Men                                                   2.0
# The Godfather Part II                                          2.0
# Pulp Fiction                                                   2.0
# Inception                                                      2.0
# The Lord of the Rings: The Fellowship of the Ring              2.0
#
#                                                    Schindler's List  \
# The Shawshank Redemption                                        1.0
# The Godfather                                                   1.0
# The Dark Knight                                                 1.0
# Schindler's List                                                0.0
# The Lord of the Rings: The Return of the King                   1.0
# 12 Angry Men                                                    1.0
# The Godfather Part II                                           1.0
# Pulp Fiction                                                    1.0
# Inception                                                       0.0
# The Lord of the Rings: The Fellowship of the Ring               1.0
#
#                                                    The Lord of the Rings: The Return of the King  \
# The Shawshank Redemption                                                                     1.0
# The Godfather                                                                                1.0
# The Dark Knight                                                                              2.0
# Schindler's List                                                                             1.0
# The Lord of the Rings: The Return of the King                                                0.0
# 12 Angry Men                                                                                 1.0
# The Godfather Part II                                                                        1.0
# Pulp Fiction                                                                                 1.0
# Inception                                                                                    2.0
# The Lord of the Rings: The Fellowship of the Ring                                            7.0
#
#                                                    12 Angry Men  \
# The Shawshank Redemption                                    1.0
# The Godfather                                               2.0
# The Dark Knight                                             2.0
# Schindler's List                                            1.0
# The Lord of the Rings: The Return of the King               1.0
# 12 Angry Men                                                0.0
# The Godfather Part II                                       2.0
# Pulp Fiction                                                2.0
# Inception                                                   0.0
# The Lord of the Rings: The Fellowship of the Ring           1.0
#
#                                                    The Godfather Part II  \
# The Shawshank Redemption                                             1.0
# The Godfather                                                        5.0
# The Dark Knight                                                      2.0
# Schindler's List                                                     1.0
# The Lord of the Rings: The Return of the King                        1.0
# 12 Angry Men                                                         2.0
# The Godfather Part II                                                0.0
# Pulp Fiction                                                         2.0
# Inception                                                            0.0
# The Lord of the Rings: The Fellowship of the Ring                    1.0
#
#                                                    Pulp Fiction  Inception  \
# The Shawshank Redemption                                    1.0        0.0
# The Godfather                                               2.0        0.0
# The Dark Knight                                             2.0        2.0
# Schindler's List                                            1.0        0.0
# The Lord of the Rings: The Return of the King               1.0        2.0
# 12 Angry Men                                                2.0        0.0
# The Godfather Part II                                       2.0        0.0
# Pulp Fiction                                                0.0        0.0
# Inception                                                   0.0        0.0
# The Lord of the Rings: The Fellowship of the Ring           1.0        2.0
#
#                                                    The Lord of the Rings: The Fellowship of the Ring
# The Shawshank Redemption                                                                         1.0
# The Godfather                                                                                    1.0
# The Dark Knight                                                                                  2.0
# Schindler's List                                                                                 1.0
# The Lord of the Rings: The Return of the King                                                    7.0
# 12 Angry Men                                                                                     1.0
# The Godfather Part II                                                                            1.0
# Pulp Fiction                                                                                     1.0
# Inception                                                                                        2.0
# The Lord of the Rings: The Fellowship of the Ring                                                0.0

# %% [markdown]
# ### Some of these are great:

# %%
most_similar_naive.T[["The Godfather", "Before Sunrise", "Batman Begins", "The Dark Knight", "The Lord of the Rings: The Return of the King", "Inception", "Interstellar", "Star Wars", "Terminator 2: Judgment Day", "Spirited Away", "City Lights", "Alien", "Rear Window", "Indiana Jones and the Last Crusade", "Avengers: Infinity War", "Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb"]].T
# Out:
#                                                                                  Most Similar Film
# title
# The Godfather                                                                The Godfather Part II
# Before Sunrise                                                                       Before Sunset
# Batman Begins                                                                      The Dark Knight
# The Dark Knight                                                                      Batman Begins
# The Lord of the Rings: The Return of the King                The Lord of the Rings: The Two Towers
# Inception                                                                             Interstellar
# Interstellar                                                                           The Martian
# Star Wars                                           Star Wars: Episode V - The Empire Strikes Back
# Terminator 2: Judgment Day                                                          The Terminator
# Spirited Away                                                                 Howl's Moving Castle
# City Lights                                                                           Modern Times
# Alien                                                                                       Aliens
# Rear Window                                                                                Vertigo
# Indiana Jones and the Last Crusade                                         Raiders of the Lost Ark
# Avengers: Infinity War                                                           Avengers: Endgame
# Dr. Strangelove or: How I Learned to Stop Worry...                                  Paths of Glory

# %% [markdown]
# ### Some are not:

# %%
most_similar_naive.T[["Hamilton", "Witness for the Prosecution", "The Wages of Fear", "Rebecca", "Trainspotting", "City of God", "The Lion King", "Pan's Labyrinth"]].T
# Out:
#                                 Most Similar Film
# title
# Hamilton                         Schindler's List
# Witness for the Prosecution                 Se7en
# The Wages of Fear                               Z
# Rebecca                      Strangers on a Train
# Trainspotting                            Big Fish
# City of God                         The Godfather
# The Lion King                     Song of the Sea
# Pan's Labyrinth                    The Green Mile

# %% [markdown]
# ## ML Beginnings

# %% [markdown]
# ### Select features

# %%
# Generate feature list, one for each genre/director/actor
genre_list = sorted(pd.unique([genre for film in movies_df["genre"] for genre in film]))
director_list = sorted(pd.unique([person for film in movies_df["directors"] for person in film]))
actor_list = sorted(pd.unique([person for film in movies_df["actors"] for person in film]))
decades = sorted(pd.unique(movies_df["decade"]))

genres = pd.DataFrame([[genre in film for genre in genre_list] for film in movies_df["genre"]], columns=genre_list)
directors = pd.DataFrame([[director in film for director in director_list] for film in movies_df["directors"]], columns=director_list)
actors = pd.DataFrame([[actor in film for actor in actor_list] for film in movies_df["actors"]], columns=actor_list)
years = pd.DataFrame([movies_df["decade"] == decade for decade in decades], index=decades).T
features_df = pd.concat([years, genres, directors, actors], axis=1)
features_df.index = movies_df["title"]
features_df.iloc[27:40, [4, 8, 20, 24, 90, 110, 177, 203]]
# Out:
#                          1960   2000  Film-Noir  Musical  Charles Chaplin  \
# title
# Life Is Beautiful       False  False      False    False            False
# Seven Samurai           False  False      False    False            False
# It's a Wonderful Life   False  False      False    False            False
# Harakiri                 True  False      False    False            False
# Gladiator               False   True      False    False            False
# Parasite                False  False      False    False            False
# Whiplash                False  False      False    False            False
# The Departed            False   True      False    False            False
# Back to the Future      False  False      False    False            False
# The Prestige            False   True      False    False            False
# Alien                   False  False      False    False            False
# Léon: The Professional  False  False      False    False            False
# Psycho                   True  False      False    False            False
#
#                         Danis Tanovic  George Seaton  Irvin Kershner
# title
# Life Is Beautiful               False          False           False
# Seven Samurai                   False          False           False
# It's a Wonderful Life           False          False           False
# Harakiri                        False          False           False
# Gladiator                       False          False           False
# Parasite                        False          False           False
# Whiplash                        False          False           False
# The Departed                    False          False           False
# Back to the Future              False          False           False
# The Prestige                    False          False           False
# Alien                           False          False           False
# Léon: The Professional          False          False           False
# Psycho                          False          False           False

# %% [markdown]
# ### Create Dataset and Model

# %%
# Create our custom Dataset class
class MovieDataset(Dataset):
    def __init__(self, features_tensor, labels):
        self.features = features_tensor
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
# Create our custom model
class Model(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(  # simple three linear layer network
            nn.Linear(channels, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 11),
        )

    def forward(self, x):
        x = self.linear_relu_stack(x)  # run through our Sequential pipeline
        return x

# %% [markdown]
# ### Train Model

# %%
# Now create variables needed for iterative training

net = Model(len(features_df.keys()))  # Create model instance
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# Convert to tensor
features = torch.tensor(np.array(features_df)).to(torch.float32)

# Train for a user who loves drama movies and hates everything else
labels = torch.tensor(["Drama" in film for film in movies_df["genre"]]).to(torch.int64) * 10

# Train and test sets, 0.8 train/0.2 test
train_size = int(len(features) * 0.8)
train_dataset = MovieDataset(features[:train_size], labels[:train_size])
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_dataset = MovieDataset(features[train_size:], labels[train_size:])
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=True)

# %%
# Training the model
for epoch in range(100):
    for i, data in enumerate(train_loader, 0):
        # basic training loop
        inputs, labels = data  # Note that this pulls from our dataset using MovieDataset's __getitem__()
        optimizer.zero_grad()
        outputs = net(inputs)  # Run our inputs through the model
        loss = criterion(outputs, labels)  # Check our model's outputs against the labels
        
        # Update the model
        loss.backward()
        optimizer.step()

print('Finished Training')
# Out:
# Finished Training

# %% [markdown]
# ### Iterative Testing

# %%
correct = 0
total = 0
for i, data in enumerate(test_loader):
    inputs, labels = data
    outputs = torch.argmax(net(inputs), axis=1)
    correct += (outputs == labels).sum()
    total += len(labels)
print("Total correctness: {:.2f} ({}/{})".format(float(correct/total), correct, total))
# Out:
# Total correctness: 1.00 (168/168)

# %% [markdown]
# # GNN Beginnings
# Initially just importing everything into GCN format, going to make movie graph next time

# %%
edge_index = torch.tensor(list(itertools.product([i for i in range(len(movies_df))], [i for i in range(len(movies_df))]))).T
labels = torch.tensor(["Drama" in film for film in movies_df["genre"]]).to(torch.int64) * 10
train_mask = torch.tensor([True for i in range(train_size)] + [False for i in range(features.shape[0] - train_size)], dtype=torch.bool)
test_mask = np.logical_not(train_mask).to(torch.bool)
data = Data(x=features.to(torch.float32), y=labels, edge_index=edge_index, train_mask=train_mask, test_mask=test_mask)  # x is the data, y is labels
loader = DataLoader(data, batch_size=32, shuffle=True)

# %% [markdown]
# ### GNN Model Class

# %%
class GCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = GCNConv(data.num_node_features, 16)
        self.conv2 = GCNConv(16, 11)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)

        return F.log_softmax(x, dim=1)

# %% [markdown]
# Use GCN just to make sure it's all working properly, this isn't the final purpose

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GCN().to(device)
data = data.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

model.train()
for epoch in range(200):
    optimizer.zero_grad()
    out = model(data)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()

# %%
model.eval()
pred = model(data).argmax(dim=1)
correct = (pred[data.test_mask] == data.y[data.test_mask]).sum()
acc = int(correct) / int(data.test_mask.sum())
print(f'Accuracy: {acc:.4f}')
# Out:
# Accuracy: 0.6964

# %% [markdown]
# ### Building the Graph Attempt 1

# %%
class GNN(torch.nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv1 = SAGEConv(channels, channels)
        self.conv2 = SAGEConv(channels, channels)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return torch.matmul(x, x.T)
    
    
def custom_loss(data, pred):
    pred = (pred >= 0.5).to(torch.float32)
    edges = (pred == 1).nonzero(as_tuple=True)
    loss_tensor = (data[edges[0]] != data[edges[1]]).float().requires_grad_(True)
    # Add in penalty for not predicting any edges
    return loss_tensor.sum()

# %%
model = GNN(channels=len(features_df.keys()))
model = model.to(device)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
# Out:
# GNN(
#   (conv1): SAGEConv(2809, 2809, aggr=mean)
#   (conv2): SAGEConv(2809, 2809, aggr=mean)
# )

# %%
transform = T.RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    disjoint_train_ratio=0.3,
    neg_sampling_ratio=0.0,
    add_negative_train_samples=False,
)

train_data, val_data, test_data = transform(data)
train_loader = LinkNeighborLoader(
    data=train_data,
    num_neighbors=[3],
    batch_size=len(train_data),
    shuffle=True,
    replace=True
)

# %%
import tqdm

for epoch in range(0, 4):
    total_loss = total_examples = 0
    for sampled_data in tqdm.tqdm(train_loader):
        optimizer.zero_grad()

        sampled_data.to(device)
        pred = model(sampled_data.x, sampled_data.edge_index)
        loss = custom_loss(sampled_data.x, pred)
        loss.backward()
        optimizer.step()
        
        total_loss += float(loss)
        total_examples += sampled_data.num_nodes
    print("Loss for epoch {}: {}".format(epoch, total_loss/total_examples))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56180/56180 [1:33:48<00:00,  9.98it/s]
#   0%|                                                                                                                                                                           | 1/56180 [00:00<1:45:31,  8.87it/s]
# Loss for epoch 0: 789.8611999623183
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56180/56180 [1:30:06<00:00, 10.39it/s]
#   0%|                                                                                                                                                                           | 1/56180 [00:00<2:12:36,  7.06it/s]
# Loss for epoch 1: 789.7026387634742
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56180/56180 [1:23:06<00:00, 11.27it/s]
#   0%|                                                                                                                                                                           | 1/56180 [00:00<1:34:19,  9.93it/s]
# Loss for epoch 2: 789.46312851767
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56180/56180 [1:14:02<00:00, 12.65it/s]
# Loss for epoch 3: 789.8017143404946

# %%
all_edges = torch.tensor([[i, j] for i in range(data.num_nodes) for j in range(data.num_nodes)]).T
output = model(data.x, all_edges)
for i in range(len(output)):
    output[i, i] = 0

output_probs, output_links = torch.topk(output, 5)
for i, l in enumerate(output_links):
    print(features_df.iloc[i].name)
    for j in l:
        print("\t->{}".format(features_df.iloc[int(j)].name))
# Out:
# The Shawshank Redemption
# 	->Se7en
# 	->The Green Mile
# 	->Short Cuts
# 	->Unforgiven
# 	->The Fugitive
# The Godfather
# 	->The Godfather Part II
# 	->Apocalypse Now
# 	->Serpico
# 	->Dog Day Afternoon
# 	->The Conversation
# The Dark Knight
# 	->Batman Begins
# 	->3:10 to Yuma
# 	->The Prestige
# 	->Children of Men
# 	->Man on Fire
# Schindler's List
# 	->Tombstone
# 	->Malcolm X
# 	->Hacksaw Ridge
# 	->Frost/Nixon
# 	->Gandhi
# The Lord of the Rings: The Return of the King
# 	->The Lord of the Rings: The Two Towers
# 	->The Lord of the Rings: The Fellowship of the Ring
# 	->Hero
# 	->Crouching Tiger, Hidden Dragon
# 	->Into the Wild
# 12 Angry Men
# 	->On the Waterfront
# 	->Elevator to the Gallows
# 	->The Killing
# 	->The Asphalt Jungle
# 	->Strangers on a Train
# The Godfather Part II
# 	->The Godfather
# 	->Apocalypse Now
# 	->Serpico
# 	->Heat
# 	->The Irishman
# Pulp Fiction
# 	->Kill Bill: Vol. 1
# 	->The Hateful Eight
# 	->The Sixth Sense
# 	->True Romance
# 	->Kill Bill: Vol. 2
# Inception
# 	->Interstellar
# 	->Mad Max: Fury Road
# 	->Star Trek Into Darkness
# 	->Rogue One: A Star Wars Story
# 	->Edge of Tomorrow
# The Lord of the Rings: The Fellowship of the Ring
# 	->The Lord of the Rings: The Return of the King
# 	->The Lord of the Rings: The Two Towers
# 	->Hero
# 	->Crouching Tiger, Hidden Dragon
# 	->Pirates of the Caribbean: The Curse of the Black Pearl
# Fight Club
# 	->Se7en
# 	->Primal Fear
# 	->The Curious Case of Benjamin Button
# 	->The Game
# 	->American History X
# Forrest Gump
# 	->Cast Away
# 	->True Romance
# 	->Saving Private Ryan
# 	->The Green Mile
# 	->The Fault in Our Stars
# The Lord of the Rings: The Two Towers
# 	->The Lord of the Rings: The Return of the King
# 	->The Lord of the Rings: The Fellowship of the Ring
# 	->Hero
# 	->Crouching Tiger, Hidden Dragon
# 	->Into the Wild
# The Good, the Bad and the Ugly
# 	->For a Few Dollars More
# 	->A Fistful of Dollars
# 	->The Wild Bunch
# 	->Once Upon a Time in the West
# 	->The Magnificent Seven
# The Matrix
# 	->Jurassic Park
# 	->Terminator 2: Judgment Day
# 	->The Fifth Element
# 	->John Wick: Chapter 4
# 	->Children of Men
# Goodfellas
# 	->Raging Bull
# 	->The Irishman
# 	->Casino
# 	->Heat
# 	->In the Name of the Father
# One Flew Over the Cuckoo's Nest
# 	->Chinatown
# 	->All That Jazz
# 	->The Sting
# 	->Deliverance
# 	->Being There
# Star Wars: Episode V - The Empire Strikes Back
# 	->Star Wars: Episode VI - Return of the Jedi
# 	->Star Wars
# 	->Raiders of the Lost Ark
# 	->Indiana Jones and the Last Crusade
# 	->Avatar
# Interstellar
# 	->The Martian
# 	->The Little Prince
# 	->Inception
# 	->The Dark Knight Rises
# 	->Mad Max: Fury Road
# Se7en
# 	->L.A. Confidential
# 	->The Girl with the Dragon Tattoo
# 	->The Usual Suspects
# 	->Zodiac
# 	->The Game
# The Silence of the Lambs
# 	->Miller's Crossing
# 	->No Country for Old Men
# 	->Carlito's Way
# 	->Hell or High Water
# 	->Run Lola Run
# Star Wars
# 	->Star Wars: Episode VI - Return of the Jedi
# 	->Star Wars: Episode V - The Empire Strikes Back
# 	->Star Wars: Episode III - Revenge of the Sith
# 	->Avatar
# 	->Zack Snyder's Justice League
# Terminator 2: Judgment Day
# 	->The Terminator
# 	->The Matrix
# 	->Jurassic Park
# 	->The Fifth Element
# 	->Children of Men
# The Green Mile
# 	->Saving Private Ryan
# 	->Dancer in the Dark
# 	->Heat
# 	->Road to Perdition
# 	->Underground
# Spirited Away
# 	->Howl's Moving Castle
# 	->WALL·E
# 	->Ponyo
# 	->Shrek
# 	->Ratatouille
# Saving Private Ryan
# 	->True Grit
# 	->The Green Mile
# 	->Jurassic Park
# 	->Empire of the Sun
# 	->Philadelphia
# City of God
# 	->No Country for Old Men
# 	->Zodiac
# 	->Dancer in the Dark
# 	->In Bruges
# 	->Adam's Apples
# Life Is Beautiful
# 	->Rushmore
# 	->Down by Law
# 	->The Graduate
# 	->True Romance
# 	->As Good as It Gets
# Seven Samurai
# 	->Rashomon
# 	->The Hidden Fortress
# 	->Ikiru
# 	->Yojimbo
# 	->High and Low
# It's a Wonderful Life
# 	->Miracle on 34th Street
# 	->Rope
# 	->Fantasia
# 	->Harry Potter and the Goblet of Fire
# 	->Let's Go! India
# Harakiri
# 	->In the Heat of the Night
# 	->Children of Men
# 	->High and Low
# 	->Yojimbo
# 	->A Fistful of Dollars
# Gladiator
# 	->Crouching Tiger, Hidden Dragon
# 	->Hero
# 	->Into the Wild
# 	->3:10 to Yuma
# 	->American Gangster
# Parasite
# 	->Black Swan
# 	->Room
# 	->The Butterfly Effect
# 	->Joker
# 	->Hell or High Water
# Whiplash
# 	->La La Land
# 	->The Broken Circle Breakdown
# 	->Sing Street
# 	->Gully Boy
# 	->A Star Is Born
# The Departed
# 	->No Country for Old Men
# 	->Road to Perdition
# 	->Nine Queens
# 	->Lucky Number Slevin
# 	->The Butterfly Effect
# Back to the Future
# 	->Back to the Future Part II
# 	->Who Framed Roger Rabbit
# 	->E.T.
# 	->The Blues Brothers
# 	->Jurassic Park
# The Prestige
# 	->The Dark Knight
# 	->Batman Begins
# 	->Children of Men
# 	->Donnie Darko
# 	->Moon
# Alien
# 	->King Kong
# 	->Aliens
# 	->Invasion of the Body Snatchers
# 	->The Martian
# 	->The Butterfly Effect
# Léon: The Professional
# 	->The Fugitive
# 	->The Fifth Element
# 	->Man on Fire
# 	->Run Lola Run
# 	->Heat
# Psycho
# 	->Saw
# 	->The Birds
# 	->The Others
# 	->Rear Window
# 	->Get Out
# Apocalypse Now
# 	->The Conversation
# 	->The Godfather Part II
# 	->The Godfather
# 	->Badlands
# 	->Patton
# The Lion King
# 	->Mulan
# 	->Into the Wild
# 	->The Iron Giant
# 	->Toy Story 2
# 	->Aladdin
# The Pianist
# 	->Into the Wild
# 	->Ray
# 	->Control
# 	->Walk the Line
# 	->Downfall
# The Usual Suspects
# 	->L.A. Confidential
# 	->Se7en
# 	->Primal Fear
# 	->A Bronx Tale
# 	->The Girl with the Dragon Tattoo
# American History X
# 	->Primal Fear
# 	->L.A. Confidential
# 	->True Romance
# 	->In Bruges
# 	->Heat
# The Intouchables
# 	->Philomena
# 	->Pride
# 	->Lion
# 	->Hacksaw Ridge
# 	->Green Book
# Once Upon a Time in the West
# 	->The Good, the Bad and the Ugly
# 	->A Fistful of Dollars
# 	->For a Few Dollars More
# 	->The Dirty Dozen
# 	->The Wild Bunch
# Casablanca
# 	->Notorious
# 	->The Best Years of Our Lives
# 	->Mildred Pierce
# 	->The Shop Around the Corner
# 	->Sabrina
# Grave of the Fireflies
# 	->Empire of the Sun
# 	->Das Boot
# 	->The Tale of The Princess Kaguya
# 	->No Man's Land
# 	->Full Metal Jacket
# Rear Window
# 	->Vertigo
# 	->Dial M for Murder
# 	->The Lady Vanishes
# 	->High Noon
# 	->Rope
# Cinema Paradiso
# 	->The Fault in Our Stars
# 	->Notorious
# 	->When Harry Met Sally...
# 	->Her
# 	->The Legend of 1900
# Modern Times
# 	->City Lights
# 	->It Happened One Night
# 	->The Graduate
# 	->The Rules of the Game
# 	->Flipped
# City Lights
# 	->Modern Times
# 	->The Rules of the Game
# 	->The Worst Person in the World
# 	->The Graduate
# 	->It Happened One Night
# Joker
# 	->The Irishman
# 	->Hell or High Water
# 	->Once Upon a Time in Anatolia
# 	->Nightcrawler
# 	->Shoplifters
# Spider-Man: Into the Spider-Verse
# 	->Kubo and the Two Strings
# 	->Edge of Tomorrow
# 	->End of Watch
# 	->The Lego Movie
# 	->Big Hero 6
# Avengers: Endgame
# 	->Avengers: Infinity War
# 	->Captain America: The Winter Soldier
# 	->Captain America: Civil War
# 	->Dawn of the Planet of the Apes
# 	->The Avengers
# Django Unchained
# 	->Once Upon a Time in Hollywood
# 	->True Grit
# 	->Ray
# 	->The Hateful Eight
# 	->The Girl with the Dragon Tattoo
# American Beauty
# 	->Se7en
# 	->L.A. Confidential
# 	->The Usual Suspects
# 	->1917
# 	->True Romance
# Raiders of the Lost Ark
# 	->Indiana Jones and the Last Crusade
# 	->E.T.
# 	->Star Wars: Episode VI - Return of the Jedi
# 	->Jurassic Park
# 	->Star Wars: Episode V - The Empire Strikes Back
# The Shining
# 	->The Fly
# 	->Into the Wild
# 	->Frankenstein
# 	->Barry Lyndon
# 	->After Hours
# Oldboy
# 	->Children of Men
# 	->The Bourne Identity
# 	->Joint Security Area
# 	->Tae Guk Gi: The Brotherhood of War
# 	->The Lives of Others
# Your Name.
# 	->A Silent Voice: The Movie
# 	->The Wind Rises
# 	->The Breadwinner
# 	->Ford v Ferrari
# 	->When Marnie Was There
# The Dark Knight Rises
# 	->Dunkirk
# 	->Ford v Ferrari
# 	->The Dark Knight
# 	->The Fighter
# 	->Batman Begins
# Avengers: Infinity War
# 	->Avengers: Endgame
# 	->Captain America: The Winter Soldier
# 	->Captain America: Civil War
# 	->Edge of Tomorrow
# 	->Iron Man
# Braveheart
# 	->Hacksaw Ridge
# 	->Malcolm X
# 	->Schindler's List
# 	->Tombstone
# 	->Hotel Rwanda
# Memento
# 	->The Bourne Identity
# 	->Saw
# 	->The Bourne Ultimatum
# 	->The Bourne Supremacy
# 	->The Others
# Aliens
# 	->Avatar
# 	->Jurassic Park
# 	->Star Trek II: The Wrath of Khan
# 	->Avatar: The Way of Water
# 	->Edge of Tomorrow
# Coco
# 	->Toy Story 3
# 	->Zootopia
# 	->Despicable Me
# 	->Toy Story 4
# 	->Wreck-It Ralph
# WALL·E
# 	->Spirited Away
# 	->Finding Nemo
# 	->Howl's Moving Castle
# 	->Stardust
# 	->Ratatouille
# Amadeus
# 	->Raging Bull
# 	->Into the Wild
# 	->The Last Emperor
# 	->Bohemian Rhapsody
# 	->Downfall
# The Lives of Others
# 	->The White Ribbon
# 	->Black Book
# 	->Match Point
# 	->The Butterfly Effect
# 	->Saw
# 3 Idiots
# 	->Lagaan: Once Upon a Time in India
# 	->The Chorus
# 	->Kal Ho Naa Ho
# 	->No Man's Land
# 	->Lost in Translation
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 	->Jojo Rabbit
# 	->The Killing
# 	->Patton
# 	->No Man's Land
# 	->The Dirty Dozen
# Capernaum
# 	->The Intouchables
# 	->True Grit
# 	->Hacksaw Ridge
# 	->Philomena
# 	->Her
# Das Boot
# 	->Empire of the Sun
# 	->Tae Guk Gi: The Brotherhood of War
# 	->Beasts of No Nation
# 	->The Bridge on the River Kwai
# 	->Full Metal Jacket
# Sunset Blvd.
# 	->Sabrina
# 	->Stalag 17
# 	->The Bridge on the River Kwai
# 	->The Killing
# 	->The Asphalt Jungle
# Witness for the Prosecution
# 	->The Girl with the Dragon Tattoo
# 	->Rope
# 	->Mother
# 	->Zodiac
# 	->Double Indemnity
# Paths of Glory
# 	->The Bridge on the River Kwai
# 	->Stalag 17
# 	->The Killing
# 	->The Caine Mutiny
# 	->Barry Lyndon
# High and Low
# 	->Rashomon
# 	->Yojimbo
# 	->The Best Offer
# 	->Wind River
# 	->The Girl with the Dragon Tattoo
# John Wick: Chapter 4
# 	->The Matrix
# 	->Run Lola Run
# 	->Kill Bill: Vol. 2
# 	->The Taking of Pelham One Two Three
# 	->The Raid: Redemption
# Top Gun: Maverick
# 	->Children of Men
# 	->Edge of Tomorrow
# 	->The Batman
# 	->Heat
# 	->True Romance
# Scarface
# 	->Carlito's Way
# 	->After Hours
# 	->Serpico
# 	->Heat
# 	->The Killer
# Good Will Hunting
# 	->True Romance
# 	->Rushmore
# 	->Saving Private Ryan
# 	->Three Colors: Red
# 	->The Fault in Our Stars
# Inglourious Basterds
# 	->Into the Wild
# 	->The Bridge on the River Kwai
# 	->Black Book
# 	->The Fall
# 	->Almost Famous
# Heat
# 	->The Irishman
# 	->Donnie Brasco
# 	->True Romance
# 	->Glengarry Glen Ross
# 	->Carlito's Way
# Requiem for a Dream
# 	->Zodiac
# 	->The Butterfly Effect
# 	->The Wrestler
# 	->Into the Wild
# 	->In Bruges
# 2001: A Space Odyssey
# 	->Planet of the Apes
# 	->Iron Man
# 	->Jurassic Park
# 	->The Fifth Element
# 	->Mad Max: Fury Road
# A Clockwork Orange
# 	->Barry Lyndon
# 	->The Godfather
# 	->The Girl with the Dragon Tattoo
# 	->Le Cercle Rouge
# 	->Paper Moon
# Eternal Sunshine of the Spotless Mind
# 	->Children of Men
# 	->The Butterfly Effect
# 	->V for Vendetta
# 	->Donnie Darko
# 	->Her
# Reservoir Dogs
# 	->Kill Bill: Vol. 2
# 	->Kill Bill: Vol. 1
# 	->Donnie Brasco
# 	->Run Lola Run
# 	->Ghost in the Shell
# Full Metal Jacket
# 	->Das Boot
# 	->Empire of the Sun
# 	->Barry Lyndon
# 	->Tae Guk Gi: The Brotherhood of War
# 	->Kagemusha
# Once Upon a Time in America
# 	->The King of Comedy
# 	->Joker
# 	->Casino
# 	->In Bruges
# 	->Raging Bull
# The Hunt
# 	->Another Round
# 	->The Celebration
# 	->True Grit
# 	->Ford v Ferrari
# 	->The Girl with the Dragon Tattoo
# Hamilton
# 	->Frost/Nixon
# 	->Hacksaw Ridge
# 	->The Last King of Scotland
# 	->Into the Wild
# 	->The King's Speech
# Toy Story
# 	->Toy Story 2
# 	->Toy Story 3
# 	->Toy Story 4
# 	->Mulan
# 	->Aladdin
# Star Wars: Episode VI - Return of the Jedi
# 	->Star Wars: Episode V - The Empire Strikes Back
# 	->Star Wars
# 	->Raiders of the Lost Ark
# 	->Indiana Jones and the Last Crusade
# 	->Ghostbusters
# Up
# 	->Monsters, Inc.
# 	->Shrek
# 	->Ponyo
# 	->Fantastic Mr. Fox
# 	->Ratatouille
# Amélie
# 	->A Very Long Engagement
# 	->Good Bye Lenin!
# 	->500 Days of Summer
# 	->Kal Ho Naa Ho
# 	->Little Miss Sunshine
# Lawrence of Arabia
# 	->Into the Wild
# 	->The Bridge on the River Kwai
# 	->Togo
# 	->Inherit the Wind
# 	->The Motorcycle Diaries
# Incendies
# 	->Prisoners
# 	->The Girl with the Dragon Tattoo
# 	->Blade Runner 2049
# 	->Arrival
# 	->Wind River
# To Kill a Mockingbird
# 	->The Girl with the Dragon Tattoo
# 	->Hell or High Water
# 	->Three Billboards Outside Ebbing, Missouri
# 	->No Country for Old Men
# 	->Dancer in the Dark
# Princess Mononoke
# 	->The Iron Giant
# 	->Batman: Mask of the Phantasm
# 	->Jurassic Park
# 	->Mulan
# 	->Porco Rosso
# Toy Story 3
# 	->Toy Story 4
# 	->Toy Story 2
# 	->Toy Story
# 	->Coco
# 	->Despicable Me
# Vertigo
# 	->Rear Window
# 	->Rope
# 	->The Lady Vanishes
# 	->Psycho
# 	->North by Northwest
# Citizen Kane
# 	->The Third Man
# 	->Rope
# 	->Gaslight
# 	->Touch of Evil
# 	->The Girl with the Dragon Tattoo
# The Sting
# 	->Butch Cassidy and the Sundance Kid
# 	->Paper Moon
# 	->In Bruges
# 	->Three Billboards Outside Ebbing, Missouri
# 	->After Hours
# North by Northwest
# 	->Rear Window
# 	->Vertigo
# 	->Edge of Tomorrow
# 	->Iron Man
# 	->Mad Max: Fury Road
# Singin' in the Rain
# 	->Sabrina
# 	->Some Like It Hot
# 	->Charade
# 	->Vertigo
# 	->Good Bye Lenin!
# Metropolis
# 	->Children of Men
# 	->The Butterfly Effect
# 	->Eternal Sunshine of the Spotless Mind
# 	->Her
# 	->Arrival
# A Separation
# 	->The Salesman
# 	->The Past
# 	->Arrival
# 	->About Elly
# 	->The Fault in Our Stars
# Ikiru
# 	->Rashomon
# 	->Seven Samurai
# 	->Into the Wild
# 	->The Seventh Seal
# 	->The African Queen
# Judgment at Nuremberg
# 	->Inherit the Wind
# 	->Guess Who's Coming to Dinner
# 	->From Here to Eternity
# 	->The Battle of Algiers
# 	->The Leopard
# The Apartment
# 	->The Graduate
# 	->Good Bye Lenin!
# 	->Sabrina
# 	->Modern Times
# 	->City Lights
# Double Indemnity
# 	->Out of the Past
# 	->Mildred Pierce
# 	->Strangers on a Train
# 	->The Maltese Falcon
# 	->Witness for the Prosecution
# The Wolf of Wall Street
# 	->The Gentlemen
# 	->Once Upon a Time in Hollywood
# 	->The Grand Budapest Hotel
# 	->Gangs of Wasseypur
# 	->Three Billboards Outside Ebbing, Missouri
# The Thing
# 	->King Kong
# 	->The Fly
# 	->E.T.
# 	->Get Out
# 	->Saw
# Spider-Man: No Way Home
# 	->Zack Snyder's Justice League
# 	->Avatar: The Way of Water
# 	->Avatar
# 	->Star Wars: Episode III - Revenge of the Sith
# 	->Demon Slayer the Movie: Mugen Train
# Jurassic Park
# 	->The Fifth Element
# 	->The Matrix
# 	->Edge of Tomorrow
# 	->Star Trek Into Darkness
# 	->E.T.
# Taxi Driver
# 	->The Irishman
# 	->Casino
# 	->The King of Comedy
# 	->The Godfather Part II
# 	->Joker
# Shutter Island
# 	->Searching
# 	->Gone Girl
# 	->Get Out
# 	->The Departed
# 	->Match Point
# No Country for Old Men
# 	->Crash
# 	->Nine Queens
# 	->American Gangster
# 	->21 Grams
# 	->Road to Perdition
# Green Book
# 	->The Intouchables
# 	->Philomena
# 	->Pride
# 	->The Big Short
# 	->Captain Fantastic
# 1917
# 	->Beasts of No Nation
# 	->Ford v Ferrari
# 	->Dunkirk
# 	->The King's Speech
# 	->I Saw the Devil
# The Truman Show
# 	->The Muppet Christmas Carol
# 	->Secrets & Lies
# 	->Underground
# 	->Primal Fear
# 	->Dead Poets Society
# Kill Bill: Vol. 1
# 	->Kill Bill: Vol. 2
# 	->The Dark Knight
# 	->3:10 to Yuma
# 	->Batman Begins
# 	->Man on Fire
# Casino
# 	->The Irishman
# 	->Goodfellas
# 	->Heat
# 	->Taxi Driver
# 	->Once Upon a Time in America
# The Sixth Sense
# 	->12 Monkeys
# 	->The Game
# 	->Gone Girl
# 	->In the Heat of the Night
# 	->Se7en
# Snatch
# 	->The Gentlemen
# 	->In Bruges
# 	->Lock, Stock and Two Smoking Barrels
# 	->Adam's Apples
# 	->No Country for Old Men
# There Will Be Blood
# 	->In Bruges
# 	->Into the Wild
# 	->The Butterfly Effect
# 	->Kal Ho Naa Ho
# 	->No Country for Old Men
# Howl's Moving Castle
# 	->Spirited Away
# 	->WALL·E
# 	->Ponyo
# 	->Shrek
# 	->Stardust
# Batman Begins
# 	->The Dark Knight
# 	->3:10 to Yuma
# 	->The Prestige
# 	->Man on Fire
# 	->Children of Men
# The Father
# 	->The Sixth Sense
# 	->The Girl with the Dragon Tattoo
# 	->The Whale
# 	->Into the Wild
# 	->Rope
# L.A. Confidential
# 	->Se7en
# 	->The Usual Suspects
# 	->The Girl with the Dragon Tattoo
# 	->Primal Fear
# 	->Rope
# A Beautiful Mind
# 	->Frost/Nixon
# 	->Into the Wild
# 	->American Gangster
# 	->Cinderella Man
# 	->The Sea Inside
# Indiana Jones and the Last Crusade
# 	->Raiders of the Lost Ark
# 	->E.T.
# 	->Star Wars: Episode V - The Empire Strikes Back
# 	->Jurassic Park
# 	->Star Wars
# Finding Nemo
# 	->Monsters, Inc.
# 	->WALL·E
# 	->Shrek
# 	->Toy Story 2
# 	->Fantastic Mr. Fox
# Gone with the Wind
# 	->City Lights
# 	->All Quiet on the Western Front
# 	->The Wizard of Oz
# 	->Modern Times
# 	->It Happened One Night
# Unforgiven
# 	->Million Dollar Baby
# 	->The Outlaw Josey Wales
# 	->The Bridges of Madison County
# 	->Gran Torino
# 	->A Fistful of Dollars
# V for Vendetta
# 	->Children of Men
# 	->Iron Man
# 	->The Butterfly Effect
# 	->District 9
# 	->Star Trek
# Die Hard
# 	->Die Hard with a Vengeance
# 	->First Blood
# 	->The Sixth Sense
# 	->Run Lola Run
# 	->Predator
# Pan's Labyrinth
# 	->The Fall
# 	->Black Book
# 	->Tae Guk Gi: The Brotherhood of War
# 	->No Man's Land
# 	->Let the Right One In
# The Elephant Man
# 	->Gandhi
# 	->Into the Wild
# 	->Raging Bull
# 	->The World's Fastest Indian
# 	->Glory
# Chinatown
# 	->The Conversation
# 	->Gone Girl
# 	->Le Cercle Rouge
# 	->In the Heat of the Night
# 	->Deliverance
# Warrior
# 	->Dunkirk
# 	->The Dark Knight Rises
# 	->The Revenant
# 	->Mad Max: Fury Road
# 	->Ford v Ferrari
# Downfall
# 	->The Last King of Scotland
# 	->Frost/Nixon
# 	->Into the Wild
# 	->Hotel Rwanda
# 	->Hacksaw Ridge
# Raging Bull
# 	->Goodfellas
# 	->The Irishman
# 	->Lagaan: Once Upon a Time in India
# 	->Once Upon a Time in America
# 	->Into the Wild
# Monty Python and the Holy Grail
# 	->Life of Brian
# 	->Star Wars
# 	->The Holy Mountain
# 	->Guardians of the Galaxy Vol. 2
# 	->Guardians of the Galaxy
# Some Like It Hot
# 	->Sabrina
# 	->The Apartment
# 	->Stalag 17
# 	->The Quiet Man
# 	->Singin' in the Rain
# Demon Slayer the Movie: Mugen Train
# 	->Wolfwalkers
# 	->Kubo and the Two Strings
# 	->Thirteen Lives
# 	->The Incredibles
# 	->Spider-Man: Into the Spider-Verse
# The Secret in Their Eyes
# 	->Talk to Her
# 	->Atonement
# 	->A Very Long Engagement
# 	->Slumdog Millionaire
# 	->Moon
# The Great Escape
# 	->The Magnificent Seven
# 	->Into the Wild
# 	->The Dirty Dozen
# 	->Inherit the Wind
# 	->A Man for All Seasons
# All About Eve
# 	->The Killing
# 	->The Bridge on the River Kwai
# 	->The Asphalt Jungle
# 	->Into the Wild
# 	->Stalag 17
# Ran
# 	->Kagemusha
# 	->Yojimbo
# 	->Tae Guk Gi: The Brotherhood of War
# 	->1917
# 	->Children of Men
# For a Few Dollars More
# 	->The Good, the Bad and the Ugly
# 	->A Fistful of Dollars
# 	->Once Upon a Time in the West
# 	->The Wild Bunch
# 	->The Outlaw Josey Wales
# The Bridge on the River Kwai
# 	->Stalag 17
# 	->Ben-Hur
# 	->Inglourious Basterds
# 	->Lawrence of Arabia
# 	->The Caine Mutiny
# Dial M for Murder
# 	->Rear Window
# 	->High Noon
# 	->Rififi
# 	->Strangers on a Train
# 	->Elevator to the Gallows
# The Treasure of the Sierra Madre
# 	->The African Queen
# 	->The Maltese Falcon
# 	->To Have and Have Not
# 	->Into the Wild
# 	->Stagecoach
# Rashomon
# 	->Seven Samurai
# 	->High and Low
# 	->The Girl with the Dragon Tattoo
# 	->Witness for the Prosecution
# 	->Ikiru
# Klaus
# 	->Fantastic Mr. Fox
# 	->Isle of Dogs
# 	->Toy Story 4
# 	->Toy Story 3
# 	->Despicable Me
# Gangs of Wasseypur
# 	->The Gentlemen
# 	->Kick-Ass
# 	->Three Billboards Outside Ebbing, Missouri
# 	->The Grand Budapest Hotel
# 	->Kingsman: The Secret Service
# Yojimbo
# 	->High and Low
# 	->The Hidden Fortress
# 	->The Butterfly Effect
# 	->A Fistful of Dollars
# 	->Seven Samurai
# Tokyo Story
# 	->Into the Wild
# 	->The Killing
# 	->Sunset Blvd.
# 	->Anatomy of a Murder
# 	->Strangers on a Train
# Z
# 	->Hell or High Water
# 	->Le Cercle Rouge
# 	->No Country for Old Men
# 	->Road to Perdition
# 	->What Ever Happened to Baby Jane?
# Children of Heaven
# 	->October Sky
# 	->The Muppet Christmas Carol
# 	->Let's Go! India
# 	->The Sandlot
# 	->Whisper of the Heart
# To Be or Not to Be
# 	->The Shop Around the Corner
# 	->The Philadelphia Story
# 	->Casablanca
# 	->The Best Years of Our Lives
# 	->Jojo Rabbit
# The Passion of Joan of Arc
# 	->The Last King of Scotland
# 	->Hacksaw Ridge
# 	->Frost/Nixon
# 	->Downfall
# 	->Into the Wild
# The Wages of Fear
# 	->Le Cercle Rouge
# 	->The Bridge on the River Kwai
# 	->Into the Wild
# 	->Deliverance
# 	->On the Waterfront
# Umberto D.
# 	->Into the Wild
# 	->The Bridge on the River Kwai
# 	->The Caine Mutiny
# 	->The Wages of Fear
# 	->Anatomy of a Murder
# The Help
# 	->Hidden Figures
# 	->La La Land
# 	->Three Billboards Outside Ebbing, Missouri
# 	->The Girl with the Dragon Tattoo
# 	->50/50
# Prisoners
# 	->The Girl with the Dragon Tattoo
# 	->Arrival
# 	->Incendies
# 	->Blade Runner 2049
# 	->Wind River
# The Grand Budapest Hotel
# 	->Isle of Dogs
# 	->Three Billboards Outside Ebbing, Missouri
# 	->The Gentlemen
# 	->End of Watch
# 	->Gangs of Wasseypur
# Mad Max: Fury Road
# 	->Edge of Tomorrow
# 	->Kubo and the Two Strings
# 	->Rogue One: A Star Wars Story
# 	->The Road Warrior
# 	->Avengers: Infinity War
# Rocky
# 	->Lagaan: Once Upon a Time in India
# 	->Let's Go! India
# 	->All the President's Men
# 	->Warrior
# 	->Enter the Dragon
# Catch Me If You Can
# 	->Road to Perdition
# 	->Man on Fire
# 	->No Country for Old Men
# 	->Into the Wild
# 	->Dancer in the Dark
# Gone Girl
# 	->The Girl with the Dragon Tattoo
# 	->Searching
# 	->Hell or High Water
# 	->The Game
# 	->Black Swan
# Pirates of the Caribbean: The Curse of the Black Pearl
# 	->Star Wars: Episode III - Revenge of the Sith
# 	->The Fall
# 	->Avatar
# 	->The Lord of the Rings: The Two Towers
# 	->The Lord of the Rings: The Return of the King
# The Big Lebowski
# 	->Barton Fink
# 	->O Brother, Where Art Thou?
# 	->Miller's Crossing
# 	->Fargo
# 	->Three Billboards Outside Ebbing, Missouri
# Blade Runner
# 	->Children of Men
# 	->The Martian
# 	->Logan
# 	->Blade Runner 2049
# 	->The Butterfly Effect
# The Exorcist
# 	->Dawn of the Dead
# 	->Deliverance
# 	->Alien
# 	->The Man Who Would Be King
# 	->What Ever Happened to Baby Jane?
# Ben-Hur
# 	->The Bridge on the River Kwai
# 	->Into the Wild
# 	->Touch of Evil
# 	->The Wages of Fear
# 	->The African Queen
# Ford v Ferrari
# 	->The Fighter
# 	->The Dark Knight Rises
# 	->True Grit
# 	->The Big Short
# 	->Hacksaw Ridge
# Harry Potter and the Deathly Hallows: Part 2
# 	->Harry Potter and the Deathly Hallows: Part 1
# 	->Harry Potter and the Goblet of Fire
# 	->Harry Potter and the Prisoner of Azkaban
# 	->Harry Potter and the Sorcerer's Stone
# 	->Stardust
# Stand by Me
# 	->Into the Wild
# 	->The Right Stuff
# 	->The Fall
# 	->The Princess Bride
# 	->Stagecoach
# Hacksaw Ridge
# 	->12 Years a Slave
# 	->The Social Network
# 	->Hidden Figures
# 	->The King's Speech
# 	->Straight Outta Compton
# The Terminator
# 	->Terminator 2: Judgment Day
# 	->Aliens
# 	->RoboCop
# 	->Children of Men
# 	->Jurassic Park
# Cool Hand Luke
# 	->Butch Cassidy and the Sundance Kid
# 	->The Sting
# 	->No Country for Old Men
# 	->In Cold Blood
# 	->To Kill a Mockingbird
# Dead Poets Society
# 	->Crimes and Misdemeanors
# 	->After Hours
# 	->Little Miss Sunshine
# 	->Do the Right Thing
# 	->No Man's Land
# The Wizard of Oz
# 	->Harry Potter and the Goblet of Fire
# 	->Stardust
# 	->Harry Potter and the Prisoner of Azkaban
# 	->Harry Potter and the Deathly Hallows: Part 1
# 	->Harry Potter and the Deathly Hallows: Part 2
# Ratatouille
# 	->Shrek
# 	->The Incredibles
# 	->Ponyo
# 	->WALL·E
# 	->Monsters, Inc.
# The Handmaiden
# 	->The Fault in Our Stars
# 	->Joker
# 	->Hell or High Water
# 	->A Star Is Born
# 	->Once Upon a Time in Anatolia
# Jaws
# 	->Deliverance
# 	->Jurassic Park
# 	->E.T.
# 	->The Taking of Pelham One Two Three
# 	->First Blood
# Three Billboards Outside Ebbing, Missouri
# 	->In Bruges
# 	->Knives Out
# 	->The Girl with the Dragon Tattoo
# 	->Kick-Ass
# 	->Hell or High Water
# Inside Out
# 	->Zootopia
# 	->Isle of Dogs
# 	->Monsters, Inc.
# 	->Toy Story 4
# 	->Klaus
# Trainspotting
# 	->True Romance
# 	->Underground
# 	->Slumdog Millionaire
# 	->Saving Private Ryan
# 	->The Sixth Sense
# Lock, Stock and Two Smoking Barrels
# 	->The Gentlemen
# 	->Gangs of Wasseypur
# 	->Run Lola Run
# 	->Snatch
# 	->Ghost in the Shell
# Logan
# 	->X-Men: Days of Future Past
# 	->Children of Men
# 	->Her
# 	->Ford v Ferrari
# 	->Arrival
# Fargo
# 	->Miller's Crossing
# 	->The Big Lebowski
# 	->Run Lola Run
# 	->Barton Fink
# 	->Carlito's Way
# Into the Wild
# 	->The Motorcycle Diaries
# 	->The Fall
# 	->Frost/Nixon
# 	->Crouching Tiger, Hidden Dragon
# 	->Hotel Rwanda
# The Sound of Music
# 	->Finding Neverland
# 	->October Sky
# 	->Inherit the Wind
# 	->Frost/Nixon
# 	->Into the Wild
# Spotlight
# 	->Dark Waters
# 	->The Intouchables
# 	->The Girl with the Dragon Tattoo
# 	->Hacksaw Ridge
# 	->The Irishman
# Room
# 	->Joker
# 	->Hell or High Water
# 	->Black Swan
# 	->Ex Machina
# 	->Wonder
# How to Train Your Dragon
# 	->How to Train Your Dragon 2
# 	->Spider-Man: Into the Spider-Verse
# 	->Kubo and the Two Strings
# 	->Big Hero 6
# 	->The Lego Movie
# Memories of Murder
# 	->Mother
# 	->Zodiac
# 	->The Girl with the Dragon Tattoo
# 	->Inside Man
# 	->Dancer in the Dark
# Monsters, Inc.
# 	->Finding Nemo
# 	->Up
# 	->Shrek
# 	->Ratatouille
# 	->The Girl Who Leapt Through Time
# Groundhog Day
# 	->Underground
# 	->Rushmore
# 	->Being John Malkovich
# 	->Short Cuts
# 	->The Muppet Christmas Carol
# Before Sunrise
# 	->Before Sunset
# 	->Before Midnight
# 	->Rushmore
# 	->Gattaca
# 	->Waking Life
# The Deer Hunter
# 	->Patton
# 	->Barry Lyndon
# 	->Apocalypse Now
# 	->All That Jazz
# 	->The Godfather Part II
# Platoon
# 	->Empire of the Sun
# 	->Das Boot
# 	->Jojo Rabbit
# 	->The Bridge on the River Kwai
# 	->Beasts of No Nation
# Rush
# 	->Ford v Ferrari
# 	->The Fighter
# 	->Lion
# 	->Ip Man
# 	->Philomena
# 12 Years a Slave
# 	->Hacksaw Ridge
# 	->Dark Waters
# 	->Hidden Figures
# 	->The King's Speech
# 	->Straight Outta Compton
# Portrait of a Lady on Fire
# 	->Her
# 	->The Broken Circle Breakdown
# 	->A Star Is Born
# 	->The Fault in Our Stars
# 	->Gone Girl
# Million Dollar Baby
# 	->Gran Torino
# 	->Lagaan: Once Upon a Time in India
# 	->Unforgiven
# 	->Let's Go! India
# 	->Into the Wild
# In the Mood for Love
# 	->Hero
# 	->Match Point
# 	->The Butterfly Effect
# 	->A Very Long Engagement
# 	->No Country for Old Men
# My Neighbor Totoro
# 	->Castle in the Sky
# 	->Kiki's Delivery Service
# 	->Spirited Away
# 	->Ponyo
# 	->Howl's Moving Castle
# Stalker
# 	->Solaris
# 	->Children of Men
# 	->The Butterfly Effect
# 	->All That Jazz
# 	->Metropolis
# Gran Torino
# 	->Million Dollar Baby
# 	->Letters from Iwo Jima
# 	->Lagaan: Once Upon a Time in India
# 	->Let's Go! India
# 	->Mystic River
# The Best Years of Our Lives
# 	->Casablanca
# 	->Notorious
# 	->To Be or Not to Be
# 	->The Shop Around the Corner
# 	->Her
# Barry Lyndon
# 	->Deliverance
# 	->The Bridge on the River Kwai
# 	->The Man Who Would Be King
# 	->Paper Moon
# 	->Inglourious Basterds
# Wild Tales
# 	->The Intouchables
# 	->Hell or High Water
# 	->Philomena
# 	->Ex Machina
# 	->Three Billboards Outside Ebbing, Missouri
# Network
# 	->Apocalypse Now
# 	->The Godfather Part II
# 	->Chinatown
# 	->The Bridge on the River Kwai
# 	->Deliverance
# A Silent Voice: The Movie
# 	->Your Name.
# 	->The Breadwinner
# 	->My Life as a Zucchini
# 	->The Wind Rises
# 	->Song of the Sea
# Before Sunset
# 	->Before Midnight
# 	->Before Sunrise
# 	->Waking Life
# 	->Match Point
# 	->The Curious Case of Benjamin Button
# Paris, Texas
# 	->The Fly
# 	->Crimes and Misdemeanors
# 	->Raging Bull
# 	->Wings of Desire
# 	->After Hours
# The Seventh Seal
# 	->Through a Glass Darkly
# 	->Wild Strawberries
# 	->Persona
# 	->The Bridge on the River Kwai
# 	->Into the Wild
# All Quiet on the Western Front
# 	->Tae Guk Gi: The Brotherhood of War
# 	->Jojo Rabbit
# 	->Into the Wild
# 	->Gone with the Wind
# 	->1917
# The Iron Giant
# 	->The Incredibles
# 	->Ratatouille
# 	->Princess Mononoke
# 	->Guardians of the Galaxy Vol. 2
# 	->Batman: Mask of the Phantasm
# Hotel Rwanda
# 	->Frost/Nixon
# 	->Into the Wild
# 	->Hacksaw Ridge
# 	->The Last King of Scotland
# 	->Downfall
# Amores Perros
# 	->21 Grams
# 	->Road to Perdition
# 	->The Butterfly Effect
# 	->Crash
# 	->Black Book
# In the Name of the Father
# 	->Donnie Brasco
# 	->Goodfellas
# 	->Se7en
# 	->Serpico
# 	->Glengarry Glen Ross
# The Man Who Shot Liberty Valance
# 	->The Searchers
# 	->Stagecoach
# 	->A Fistful of Dollars
# 	->The Dirty Dozen
# 	->Red River
# The Third Man
# 	->Shadow of a Doubt
# 	->The Big Sleep
# 	->Citizen Kane
# 	->The Maltese Falcon
# 	->Rebecca
# Rebecca
# 	->Notorious
# 	->Rope
# 	->Mildred Pierce
# 	->Out of the Past
# 	->The Maltese Falcon
# On the Waterfront
# 	->A Streetcar Named Desire
# 	->Rififi
# 	->Hell or High Water
# 	->Elevator to the Gallows
# 	->No Country for Old Men
# Persona
# 	->Wild Strawberries
# 	->Through a Glass Darkly
# 	->In the Heat of the Night
# 	->What Ever Happened to Baby Jane?
# 	->The Butterfly Effect
# The Celebration
# 	->Another Round
# 	->Adam's Apples
# 	->The Hunt
# 	->True Romance
# 	->Underground
# It Happened One Night
# 	->Modern Times
# 	->City Lights
# 	->Gone with the Wind
# 	->Mr. Smith Goes to Washington
# 	->Duck Soup
# The Grapes of Wrath
# 	->Stagecoach
# 	->Rope
# 	->Out of the Past
# 	->Miracle on 34th Street
# 	->It's a Wonderful Life
# Three Colors: Red
# 	->The Double Life of Véronique
# 	->L.A. Confidential
# 	->True Romance
# 	->Three Colors: Blue
# 	->The Sixth Sense
# Yi Yi: A One and a Two...
# 	->Slumdog Millionaire
# 	->Talk to Her
# 	->Match Point
# 	->Eternal Sunshine of the Spotless Mind
# 	->The Secret in Their Eyes
# Farewell My Concubine
# 	->The Legend of 1900
# 	->True Romance
# 	->The Broken Circle Breakdown
# 	->A Star Is Born
# 	->Happy Together
# Paper Moon
# 	->The Sting
# 	->Knives Out
# 	->Barry Lyndon
# 	->After Hours
# 	->The Gentlemen
# Wild Strawberries
# 	->Persona
# 	->The Seventh Seal
# 	->Sabrina
# 	->The African Queen
# 	->Vertigo
# Underground
# 	->Groundhog Day
# 	->Being John Malkovich
# 	->Secrets & Lies
# 	->Rushmore
# 	->The Muppet Christmas Carol
# Sunrise
# 	->Metropolis
# 	->The Fault in Our Stars
# 	->Cinema Paradiso
# 	->Notorious
# 	->True Romance
# Fanny and Alexander
# 	->Into the Wild
# 	->The Right Stuff
# 	->Cinema Paradiso
# 	->Das Boot
# 	->Crimes and Misdemeanors
# Inherit the Wind
# 	->A Man for All Seasons
# 	->Hacksaw Ridge
# 	->Dark Waters
# 	->Frost/Nixon
# 	->Butch Cassidy and the Sundance Kid
# Mr. Smith Goes to Washington
# 	->City Lights
# 	->The Rules of the Game
# 	->Modern Times
# 	->It's a Wonderful Life
# 	->It Happened One Night
# A Woman Under the Influence
# 	->The Last Picture Show
# 	->Harold and Maude
# 	->True Romance
# 	->Le Cercle Rouge
# 	->Manhattan
# The Battle of Algiers
# 	->Jojo Rabbit
# 	->Tae Guk Gi: The Brotherhood of War
# 	->Land of Mine
# 	->Zulu
# 	->In the Heat of the Night
# Wolf Children
# 	->The Breadwinner
# 	->The Tale of The Princess Kaguya
# 	->When Marnie Was There
# 	->Your Name.
# 	->Dawn of the Planet of the Apes
# The Hidden Fortress
# 	->Seven Samurai
# 	->Rashomon
# 	->Yojimbo
# 	->Hero
# 	->The Lord of the Rings: The Two Towers
# Lagaan: Once Upon a Time in India
# 	->3 Idiots
# 	->Dancer in the Dark
# 	->Kal Ho Naa Ho
# 	->Let's Go! India
# 	->Remember the Titans
# Winter Sleep
# 	->Once Upon a Time in Anatolia
# 	->True Grit
# 	->Hacksaw Ridge
# 	->Philomena
# 	->The Intouchables
# Ace in the Hole
# 	->Sunset Blvd.
# 	->Out of the Past
# 	->The Asphalt Jungle
# 	->Touch of Evil
# 	->Stalag 17
# Rififi
# 	->Elevator to the Gallows
# 	->On the Waterfront
# 	->Hell or High Water
# 	->No Country for Old Men
# 	->Road to Perdition
# Tangerines
# 	->Beasts of No Nation
# 	->Land of Mine
# 	->Jojo Rabbit
# 	->The Girl with the Dragon Tattoo
# 	->True Grit
# Let's Go! India
# 	->Veer-Zaara
# 	->Lagaan: Once Upon a Time in India
# 	->Kal Ho Naa Ho
# 	->Finding Neverland
# 	->Into the Wild
# The Circus
# 	->City Lights
# 	->Modern Times
# 	->My Neighbor Totoro
# 	->It Happened One Night
# 	->The Princess Bride
# Dune
# 	->Spider-Man: No Way Home
# 	->Hero
# 	->Crouching Tiger, Hidden Dragon
# 	->Zack Snyder's Justice League
# 	->Gladiator
# Blade Runner 2049
# 	->Sicario
# 	->Arrival
# 	->The Girl with the Dragon Tattoo
# 	->Prisoners
# 	->Ford v Ferrari
# Black Swan
# 	->Gone Girl
# 	->Hell or High Water
# 	->Joker
# 	->Ex Machina
# 	->Room
# Guardians of the Galaxy
# 	->Guardians of the Galaxy Vol. 2
# 	->Kingsman: The Secret Service
# 	->The Lego Movie
# 	->Star Trek Into Darkness
# 	->End of Watch
# Deadpool
# 	->Deadpool 2
# 	->The Gentlemen
# 	->Kick-Ass
# 	->Kingsman: The Secret Service
# 	->Gangs of Wasseypur
# La La Land
# 	->Whiplash
# 	->Sing Street
# 	->The Big Short
# 	->Philomena
# 	->The Broken Circle Breakdown
# The Princess Bride
# 	->E.T.
# 	->The Goonies
# 	->The Blues Brothers
# 	->Back to the Future Part II
# 	->My Neighbor Totoro
# Her
# 	->Arrival
# 	->The Broken Circle Breakdown
# 	->Joker
# 	->The Girl with the Dragon Tattoo
# 	->Match Point
# Donnie Darko
# 	->Zodiac
# 	->Moon
# 	->The Prestige
# 	->The Butterfly Effect
# 	->Children of Men
# Dances with Wolves
# 	->The Lion King
# 	->Into the Wild
# 	->Die Hard with a Vengeance
# 	->Stagecoach
# 	->Mulan
# The Avengers
# 	->Captain America: Civil War
# 	->Captain America: The Winter Soldier
# 	->Avengers: Infinity War
# 	->Iron Man
# 	->Avengers: Endgame
# Zack Snyder's Justice League
# 	->Avatar: The Way of Water
# 	->Spider-Man: No Way Home
# 	->Avatar
# 	->Kingsman: The Secret Service
# 	->Star Wars
# Zootopia
# 	->Isle of Dogs
# 	->Toy Story 3
# 	->Despicable Me
# 	->Toy Story 4
# 	->Ratatouille
# The Martian
# 	->Interstellar
# 	->Mad Max: Fury Road
# 	->Edge of Tomorrow
# 	->True Grit
# 	->Into the Wild
# The Revenant
# 	->Mad Max: Fury Road
# 	->Dunkirk
# 	->Dawn of the Planet of the Apes
# 	->Warrior
# 	->Kingsman: The Secret Service
# Casino Royale
# 	->Skyfall
# 	->The Bourne Supremacy
# 	->Iron Man
# 	->District 9
# 	->The Butterfly Effect
# CODA
# 	->The Chorus
# 	->La La Land
# 	->Sing Street
# 	->The Banshees of Inisherin
# 	->Another Round
# Sin City
# 	->No Country for Old Men
# 	->Road to Perdition
# 	->Nine Queens
# 	->Lucky Number Slevin
# 	->The Bourne Identity
# The Incredibles
# 	->Ratatouille
# 	->The Iron Giant
# 	->Star Wars: Episode III - Revenge of the Sith
# 	->Kung Fu Panda
# 	->Captain America: The Winter Soldier
# Rain Man
# 	->Crimes and Misdemeanors
# 	->The Right Stuff
# 	->Portrait of a Lady on Fire
# 	->All the President's Men
# 	->The Fly
# The Bourne Ultimatum
# 	->The Bourne Supremacy
# 	->The Bourne Identity
# 	->The Others
# 	->District 9
# 	->Saw
# Scent of a Woman
# 	->Heat
# 	->Donnie Brasco
# 	->The Game
# 	->Glengarry Glen Ross
# 	->Children of Heaven
# The Imitation Game
# 	->Argo
# 	->Hacksaw Ridge
# 	->12 Years a Slave
# 	->Ford v Ferrari
# 	->Hell or High Water
# Planet of the Apes
# 	->2001: A Space Odyssey
# 	->Mad Max: Fury Road
# 	->Into the Wild
# 	->E.T.
# 	->Iron Man
# Aladdin
# 	->Moana
# 	->Toy Story 2
# 	->Mulan
# 	->Porco Rosso
# 	->Ratatouille
# 12 Monkeys
# 	->The Sixth Sense
# 	->Se7en
# 	->The Bourne Supremacy
# 	->The Butterfly Effect
# 	->The Game
# Soul
# 	->Monsters, Inc.
# 	->The Mitchells vs the Machines
# 	->Puss in Boots: The Last Wish
# 	->Up
# 	->The Triplets of Belleville
# Magnolia
# 	->Boogie Nights
# 	->The Fugitive
# 	->Happiness
# 	->Children of Men
# 	->Short Cuts
# Big Fish
# 	->The Fall
# 	->Almost Famous
# 	->Star Wars: Episode III - Revenge of the Sith
# 	->Into the Wild
# 	->Crouching Tiger, Hidden Dragon
# Ip Man
# 	->Ford v Ferrari
# 	->Children of Men
# 	->Into the Wild
# 	->Tae Guk Gi: The Brotherhood of War
# 	->Man on Fire
# Life of Brian
# 	->Monty Python and the Holy Grail
# 	->Love and Death
# 	->Paper Moon
# 	->Annie Hall
# 	->Toy Story 3
# Slumdog Millionaire
# 	->No Country for Old Men
# 	->3-Iron
# 	->In Bruges
# 	->Road to Perdition
# 	->Zodiac
# Beauty and the Beast
# 	->The Nightmare Before Christmas
# 	->Kiki's Delivery Service
# 	->The Iron Giant
# 	->Spirited Away
# 	->Whisper of the Heart
# The Graduate
# 	->Modern Times
# 	->City Lights
# 	->The Apartment
# 	->Harold and Maude
# 	->500 Days of Summer
# What Ever Happened to Baby Jane?
# 	->In the Heat of the Night
# 	->Rosemary's Baby
# 	->Psycho
# 	->The Birds
# 	->The Butterfly Effect
# Perfect Blue
# 	->Ghost in the Shell
# 	->L.A. Confidential
# 	->Se7en
# 	->True Romance
# 	->Millennium Actress
# The Maltese Falcon
# 	->The Big Sleep
# 	->Rope
# 	->Mildred Pierce
# 	->To Have and Have Not
# 	->The Asphalt Jungle
# The Pursuit of Happyness
# 	->Into the Wild
# 	->Seven Pounds
# 	->Crash
# 	->Frost/Nixon
# 	->Finding Neverland
# JFK
# 	->The Sixth Sense
# 	->The Dark Knight Rises
# 	->Hidden Figures
# 	->All the President's Men
# 	->Gattaca
# Kill Bill: Vol. 2
# 	->Kill Bill: Vol. 1
# 	->Taken
# 	->Reservoir Dogs
# 	->District 9
# 	->The Bourne Identity
# The King's Speech
# 	->Hacksaw Ridge
# 	->Hidden Figures
# 	->Dark Waters
# 	->12 Years a Slave
# 	->Lion
# Akira
# 	->Millennium Actress
# 	->Kubo and the Two Strings
# 	->Children of Men
# 	->Spider-Man: Into the Spider-Verse
# 	->The Killer
# Cinderella Man
# 	->American Gangster
# 	->Into the Wild
# 	->A Beautiful Mind
# 	->Match Point
# 	->Slumdog Millionaire
# Chungking Express
# 	->In Bruges
# 	->Three Billboards Outside Ebbing, Missouri
# 	->After Hours
# 	->Paper Moon
# 	->True Romance
# Rosemary's Baby
# 	->What Ever Happened to Baby Jane?
# 	->In the Heat of the Night
# 	->The Birds
# 	->Inherit the Wind
# 	->Children of Men
# Dog Day Afternoon
# 	->Serpico
# 	->The Godfather
# 	->The Irishman
# 	->Papillon
# 	->Catch Me If You Can
# Do the Right Thing
# 	->After Hours
# 	->Dead Poets Society
# 	->Crimes and Misdemeanors
# 	->The Purple Rose of Cairo
# 	->Miracle on 34th Street
# Lion
# 	->The Intouchables
# 	->Philomena
# 	->Hacksaw Ridge
# 	->The Girl with the Dragon Tattoo
# 	->The King's Speech
# Papillon
# 	->Serpico
# 	->Dog Day Afternoon
# 	->Le Cercle Rouge
# 	->Paper Moon
# 	->Spotlight
# Blood Diamond
# 	->The Butterfly Effect
# 	->The Departed
# 	->Into the Wild
# 	->No Country for Old Men
# 	->The Fall
# Young Frankenstein
# 	->Blazing Saddles
# 	->Paper Moon
# 	->Willy Wonka & the Chocolate Factory
# 	->Harold and Maude
# 	->Life of Brian
# Butch Cassidy and the Sundance Kid
# 	->The Sting
# 	->Cool Hand Luke
# 	->Inherit the Wind
# 	->In Cold Blood
# 	->Catch Me If You Can
# Dogville
# 	->Dancer in the Dark
# 	->No Country for Old Men
# 	->In Bruges
# 	->Inside Man
# 	->Zodiac
# Annie Hall
# 	->Manhattan
# 	->Love and Death
# 	->Harold and Maude
# 	->Crimes and Misdemeanors
# 	->The Purple Rose of Cairo
# Rio Bravo
# 	->Red River
# 	->High Noon
# 	->The Searchers
# 	->Stagecoach
# 	->Into the Wild
# Sling Blade
# 	->Saving Private Ryan
# 	->The Muppet Christmas Carol
# 	->True Romance
# 	->Children of Heaven
# 	->L.A. Confidential
# Solaris
# 	->Stalker
# 	->The Conversation
# 	->Arrival
# 	->The Butterfly Effect
# 	->Moon
# Fiddler on the Roof
# 	->Willy Wonka & the Chocolate Factory
# 	->All That Jazz
# 	->Veer-Zaara
# 	->Cabaret
# 	->Kal Ho Naa Ho
# Roman Holiday
# 	->Sabrina
# 	->The Quiet Man
# 	->Some Like It Hot
# 	->Charade
# 	->The Purple Rose of Cairo
# Gandhi
# 	->Schindler's List
# 	->12 Years a Slave
# 	->A Man for All Seasons
# 	->Glory
# 	->The Killing Fields
# Nausicaä of the Valley of the Wind
# 	->Ponyo
# 	->Castle in the Sky
# 	->Howl's Moving Castle
# 	->Back to the Future Part II
# 	->Spirited Away
# Being There
# 	->Harold and Maude
# 	->The Sting
# 	->Three Billboards Outside Ebbing, Missouri
# 	->Paper Moon
# 	->Philomena
# The Last Picture Show
# 	->True Grit
# 	->Paper Moon
# 	->Harold and Maude
# 	->Slumdog Millionaire
# 	->Hell or High Water
# 8½
# 	->La Dolce Vita
# 	->The Leopard
# 	->Once Upon a Time in the West
# 	->Into the Wild
# 	->In the Heat of the Night
# Castle in the Sky
# 	->Spirited Away
# 	->My Neighbor Totoro
# 	->Howl's Moving Castle
# 	->Nausicaä of the Valley of the Wind
# 	->E.T.
# Pink Floyd: The Wall
# 	->The Chorus
# 	->The Double Life of Véronique
# 	->CODA
# 	->Pan's Labyrinth
# 	->The Fall
# La Dolce Vita
# 	->8½
# 	->The Graduate
# 	->Miracle on 34th Street
# 	->Kal Ho Naa Ho
# 	->The Rules of the Game
# Who's Afraid of Virginia Woolf?
# 	->The Graduate
# 	->Into the Wild
# 	->Inherit the Wind
# 	->What Ever Happened to Baby Jane?
# 	->To Kill a Mockingbird
# Wolfwalkers
# 	->Demon Slayer the Movie: Mugen Train
# 	->The Iron Giant
# 	->Spider-Man: Into the Spider-Verse
# 	->Thirteen Lives
# 	->Zack Snyder's Justice League
# Mommy
# 	->True Grit
# 	->1917
# 	->The Fault in Our Stars
# 	->Arrival
# 	->The Girl with the Dragon Tattoo
# High Noon
# 	->Rear Window
# 	->Dial M for Murder
# 	->Rififi
# 	->True Grit
# 	->Elevator to the Gallows
# Anatomy of a Murder
# 	->Rear Window
# 	->Rope
# 	->Vertigo
# 	->Witness for the Prosecution
# 	->The Girl with the Dragon Tattoo
# Wings of Desire
# 	->The Purple Rose of Cairo
# 	->Cinema Paradiso
# 	->The Curious Case of Benjamin Button
# 	->Pink Floyd: The Wall
# 	->Mr. Nobody
# Mirror
# 	->Into the Wild
# 	->Solaris
# 	->Hacksaw Ridge
# 	->Dog Day Afternoon
# 	->Serpico
# Infernal Affairs
# 	->Hero
# 	->3:10 to Yuma
# 	->Man on Fire
# 	->The Chaser
# 	->Elite Squad
# The Night of the Hunter
# 	->Strangers on a Train
# 	->The Asphalt Jungle
# 	->The Killing
# 	->Out of the Past
# 	->Touch of Evil
# Touch of Evil
# 	->The Asphalt Jungle
# 	->Strangers on a Train
# 	->The Killing
# 	->Mildred Pierce
# 	->The Night of the Hunter
# The Straight Story
# 	->Donnie Brasco
# 	->October Sky
# 	->Ford v Ferrari
# 	->Malcolm X
# 	->Goodfellas
# The Hustler
# 	->Butch Cassidy and the Sundance Kid
# 	->Cool Hand Luke
# 	->Lagaan: Once Upon a Time in India
# 	->Remember the Titans
# 	->Let's Go! India
# The Tale of The Princess Kaguya
# 	->The Breadwinner
# 	->When Marnie Was There
# 	->Wolf Children
# 	->Coraline
# 	->My Life as a Zucchini
# Elite Squad
# 	->Elite Squad 2: The Enemy Within
# 	->The Dark Knight
# 	->Batman Begins
# 	->Man on Fire
# 	->3:10 to Yuma
# The Legend of 1900
# 	->Farewell My Concubine
# 	->True Romance
# 	->Gully Boy
# 	->The Fault in Our Stars
# 	->The Broken Circle Breakdown
# The Leopard
# 	->Inherit the Wind
# 	->A Man for All Seasons
# 	->The Longest Day
# 	->The Great Escape
# 	->Zulu
# Song of the Sea
# 	->The Little Prince
# 	->Spider-Man: Into the Spider-Verse
# 	->Kubo and the Two Strings
# 	->The Breadwinner
# 	->The Wind Rises
# Secrets & Lies
# 	->Underground
# 	->Naked
# 	->Groundhog Day
# 	->Rushmore
# 	->The Muppet Christmas Carol
# Sweet Smell of Success
# 	->The Asphalt Jungle
# 	->The Killing
# 	->Strangers on a Train
# 	->Touch of Evil
# 	->Sunset Blvd.
# The Diving Bell and the Butterfly
# 	->Into the Wild
# 	->Frost/Nixon
# 	->The Sea Inside
# 	->Finding Neverland
# 	->Walk the Line
# Stalag 17
# 	->Sabrina
# 	->The Bridge on the River Kwai
# 	->Sunset Blvd.
# 	->Jojo Rabbit
# 	->No Man's Land
# Out of the Past
# 	->Mildred Pierce
# 	->Double Indemnity
# 	->Rope
# 	->The Night of the Hunter
# 	->The Maltese Falcon
# Brief Encounter
# 	->The Shop Around the Corner
# 	->Notorious
# 	->Rope
# 	->The Fault in Our Stars
# 	->Doctor Zhivago
# Spring, Summer, Fall, Winter... and Spring
# 	->3-Iron
# 	->Slumdog Millionaire
# 	->Eternal Sunshine of the Spotless Mind
# 	->The Butterfly Effect
# 	->Match Point
# Nobody Knows
# 	->No Country for Old Men
# 	->The Butterfly Effect
# 	->Into the Wild
# 	->Dancer in the Dark
# 	->In Bruges
# Persepolis
# 	->Into the Wild
# 	->Dancer in the Dark
# 	->Finding Neverland
# 	->Ip Man
# 	->The Wind Rises
# Black Cat, White Cat
# 	->True Romance
# 	->Lock, Stock and Two Smoking Barrels
# 	->Underground
# 	->Rushmore
# 	->As Good as It Gets
# The Sea Inside
# 	->Into the Wild
# 	->No Country for Old Men
# 	->Finding Neverland
# 	->Frost/Nixon
# 	->The Last King of Scotland
# Departures
# 	->Almost Famous
# 	->Dancer in the Dark
# 	->Into the Wild
# 	->In Bruges
# 	->Lagaan: Once Upon a Time in India
# Goodbye, Children
# 	->Das Boot
# 	->Barry Lyndon
# 	->Empire of the Sun
# 	->Lagaan: Once Upon a Time in India
# 	->Beasts of No Nation
# Central Station
# 	->True Romance
# 	->Saving Private Ryan
# 	->The Muppet Christmas Carol
# 	->Underground
# 	->Into the Wild
# The Shop Around the Corner
# 	->To Be or Not to Be
# 	->Rope
# 	->The Philadelphia Story
# 	->Notorious
# 	->Modern Times
# Elite Squad 2: The Enemy Within
# 	->Elite Squad
# 	->I Saw the Devil
# 	->Sicario
# 	->The Girl with the Dragon Tattoo
# 	->Ford v Ferrari
# Tae Guk Gi: The Brotherhood of War
# 	->Children of Men
# 	->Hero
# 	->Black Book
# 	->Pan's Labyrinth
# 	->No Man's Land
# Everything Everywhere All at Once
# 	->Zack Snyder's Justice League
# 	->Guardians of the Galaxy Vol. 2
# 	->The Mitchells vs the Machines
# 	->Kingsman: The Secret Service
# 	->Guardians of the Galaxy
# Puss in Boots: The Last Wish
# 	->The Mitchells vs the Machines
# 	->Soul
# 	->Ratatouille
# 	->The Girl Who Leapt Through Time
# 	->The Triplets of Belleville
# Avatar
# 	->Avatar: The Way of Water
# 	->Star Wars: Episode III - Revenge of the Sith
# 	->Aliens
# 	->Iron Man
# 	->The Fall
# Titanic
# 	->Sense and Sensibility
# 	->Rushmore
# 	->True Romance
# 	->The Legend of 1900
# 	->Underground
# RRR
# 	->Children of Men
# 	->Zack Snyder's Justice League
# 	->The Batman
# 	->Man on Fire
# 	->Crouching Tiger, Hidden Dragon
# Knives Out
# 	->The Girl with the Dragon Tattoo
# 	->Three Billboards Outside Ebbing, Missouri
# 	->The Gentlemen
# 	->In Bruges
# 	->Wind River
# Children of Men
# 	->V for Vendetta
# 	->Serenity
# 	->The Dark Knight
# 	->The Bourne Identity
# 	->Iron Man
# The Bourne Identity
# 	->The Bourne Supremacy
# 	->The Bourne Ultimatum
# 	->Children of Men
# 	->The Others
# 	->Saw
# Mulholland Drive
# 	->21 Grams
# 	->The Lives of Others
# 	->Eastern Promises
# 	->The White Ribbon
# 	->The Butterfly Effect
# Harry Potter and the Prisoner of Azkaban
# 	->Harry Potter and the Goblet of Fire
# 	->Harry Potter and the Deathly Hallows: Part 2
# 	->Harry Potter and the Deathly Hallows: Part 1
# 	->Harry Potter and the Sorcerer's Stone
# 	->Stardust
# In Bruges
# 	->The Banshees of Inisherin
# 	->Three Billboards Outside Ebbing, Missouri
# 	->Adam's Apples
# 	->Dancer in the Dark
# 	->No Man's Land
# Arrival
# 	->Her
# 	->Wind River
# 	->Blade Runner 2049
# 	->Prisoners
# 	->The Girl with the Dragon Tattoo
# Iron Man
# 	->Serenity
# 	->Avengers: Infinity War
# 	->Star Trek
# 	->Children of Men
# 	->District 9
# Almost Famous
# 	->Big Fish
# 	->Into the Wild
# 	->The Fall
# 	->Hero
# 	->Kal Ho Naa Ho
# Shrek
# 	->Tokyo Godfathers
# 	->Ratatouille
# 	->Ponyo
# 	->Finding Nemo
# 	->The Girl Who Leapt Through Time
# Boogie Nights
# 	->Magnolia
# 	->The Fugitive
# 	->Children of Men
# 	->The Sixth Sense
# 	->Children of Heaven
# Thor: Ragnarok
# 	->Avengers: Infinity War
# 	->Hunt for the Wilderpeople
# 	->Kingsman: The Secret Service
# 	->Deadpool 2
# 	->Guardians of the Galaxy Vol. 2
# Jojo Rabbit
# 	->No Man's Land
# 	->Three Billboards Outside Ebbing, Missouri
# 	->Beasts of No Nation
# 	->Hunt for the Wilderpeople
# 	->The Intouchables
# Bohemian Rhapsody
# 	->Hacksaw Ridge
# 	->Ford v Ferrari
# 	->12 Years a Slave
# 	->The Social Network
# 	->Lion
# True Romance
# 	->Man on Fire
# 	->Rushmore
# 	->Slumdog Millionaire
# 	->Se7en
# 	->Heat
# E.T.
# 	->Jurassic Park
# 	->Raiders of the Lost Ark
# 	->Indiana Jones and the Last Crusade
# 	->Back to the Future Part II
# 	->Aliens
# Edge of Tomorrow
# 	->Mad Max: Fury Road
# 	->Avengers: Infinity War
# 	->Captain America: The Winter Soldier
# 	->Rogue One: A Star Wars Story
# 	->Spider-Man: Into the Spider-Verse
# The Perks of Being a Wallflower
# 	->Wonder
# 	->The Girl with the Dragon Tattoo
# 	->True Grit
# 	->Lion
# 	->Hell or High Water
# Fantastic Mr. Fox
# 	->Shrek
# 	->Finding Nemo
# 	->Tokyo Godfathers
# 	->Ratatouille
# 	->The Girl Who Leapt Through Time
# Mystic River
# 	->Inside Man
# 	->Mother
# 	->Zodiac
# 	->Gone Baby Gone
# 	->Memories of Murder
# Star Trek
# 	->Star Trek Into Darkness
# 	->Iron Man
# 	->Star Trek II: The Wrath of Khan
# 	->Jurassic Park
# 	->Serenity
# District 9
# 	->The Butterfly Effect
# 	->Children of Men
# 	->The Bourne Supremacy
# 	->Iron Man
# 	->The Bourne Ultimatum
# Marriage Story
# 	->Her
# 	->The Fault in Our Stars
# 	->Match Point
# 	->A Star Is Born
# 	->The Broken Circle Breakdown
# Wonder
# 	->Room
# 	->True Grit
# 	->The Breadwinner
# 	->Ford v Ferrari
# 	->I Saw the Devil
# Carlito's Way
# 	->21 Grams
# 	->No Country for Old Men
# 	->Miller's Crossing
# 	->The Game
# 	->Scarface
# Crouching Tiger, Hidden Dragon
# 	->Hero
# 	->Into the Wild
# 	->Letters from Iwo Jima
# 	->Gladiator
# 	->The Count of Monte Cristo
# Shaun of the Dead
# 	->Hot Fuzz
# 	->Shrek
# 	->Tokyo Godfathers
# 	->Kal Ho Naa Ho
# 	->Good Bye Lenin!
# X-Men: Days of Future Past
# 	->Logan
# 	->Edge of Tomorrow
# 	->Mad Max: Fury Road
# 	->X: First Class
# 	->Captain America: The Winter Soldier
# Boyhood
# 	->Before Midnight
# 	->The Intouchables
# 	->Lion
# 	->Hacksaw Ridge
# 	->Her
# Life of Pi
# 	->Interstellar
# 	->The Hobbit: An Unexpected Journey
# 	->Crouching Tiger, Hidden Dragon
# 	->The Fall
# 	->Dawn of the Planet of the Apes
# The Blues Brothers
# 	->Ghostbusters
# 	->Kingsman: The Secret Service
# 	->Back to the Future Part II
# 	->Guardians of the Galaxy Vol. 2
# 	->Aliens
# Edward Scissorhands
# 	->Groundhog Day
# 	->True Romance
# 	->The Curious Case of Benjamin Button
# 	->Underground
# 	->Rushmore
# Dallas Buyers Club
# 	->The Intouchables
# 	->Hacksaw Ridge
# 	->Lion
# 	->Ford v Ferrari
# 	->The Irishman
# The Adventures of Robin Hood
# 	->Guardians of the Galaxy Vol. 2
# 	->Skyfall
# 	->Edge of Tomorrow
# 	->Iron Man
# 	->Spider-Man: Into the Spider-Verse
# The Wrestler
# 	->Lagaan: Once Upon a Time in India
# 	->Remember the Titans
# 	->Let's Go! India
# 	->Million Dollar Baby
# 	->Into the Wild
# The Nightmare Before Christmas
# 	->Beauty and the Beast
# 	->Coraline
# 	->The Iron Giant
# 	->Whisper of the Heart
# 	->Kiki's Delivery Service
# Spartacus
# 	->Into the Wild
# 	->Lawrence of Arabia
# 	->Inherit the Wind
# 	->Togo
# 	->A Man for All Seasons
# Toy Story 2
# 	->Toy Story
# 	->Toy Story 3
# 	->Toy Story 4
# 	->Finding Nemo
# 	->Monsters, Inc.
# A Streetcar Named Desire
# 	->On the Waterfront
# 	->The Bridge on the River Kwai
# 	->East of Eden
# 	->Rififi
# 	->The Killing
# Brazil
# 	->The Fly
# 	->The Butterfly Effect
# 	->Raging Bull
# 	->Arrival
# 	->Her
# This Is Spinal Tap
# 	->When Harry Met Sally...
# 	->After Hours
# 	->CODA
# 	->The Princess Bride
# 	->Crimes and Misdemeanors
# Ghost in the Shell
# 	->Run Lola Run
# 	->End of Watch
# 	->The Iron Giant
# 	->Lock, Stock and Two Smoking Barrels
# 	->Perfect Blue
# A Fistful of Dollars
# 	->For a Few Dollars More
# 	->The Good, the Bad and the Ugly
# 	->The Wild Bunch
# 	->Children of Men
# 	->Yojimbo
# The Searchers
# 	->Stagecoach
# 	->The Man Who Shot Liberty Valance
# 	->The Quiet Man
# 	->Into the Wild
# 	->High Noon
# The Raid 2
# 	->The Raid: Redemption
# 	->End of Watch
# 	->Kill Bill: Vol. 2
# 	->Nightcrawler
# 	->Gangs of Wasseypur
# Before Midnight
# 	->Before Sunset
# 	->Before Sunrise
# 	->The Fault in Our Stars
# 	->Boyhood
# 	->Her
# All the President's Men
# 	->Deliverance
# 	->Le Cercle Rouge
# 	->Frost/Nixon
# 	->The Conversation
# 	->The Butterfly Effect
# Doctor Zhivago
# 	->In the Heat of the Night
# 	->The Bridge on the River Kwai
# 	->Zulu
# 	->Brief Encounter
# 	->The Battle of Algiers
# The Wild Bunch
# 	->The Dirty Dozen
# 	->A Fistful of Dollars
# 	->The Good, the Bad and the Ugly
# 	->Demon Slayer the Movie: Mugen Train
# 	->End of Watch
# Let the Right One In
# 	->The Fall
# 	->Pan's Labyrinth
# 	->Big Fish
# 	->Millennium Actress
# 	->Hero
# Bound by Honor
# 	->L.A. Confidential
# 	->Carlito's Way
# 	->True Romance
# 	->The Fugitive
# 	->Heat
# Hero
# 	->Crouching Tiger, Hidden Dragon
# 	->The Lord of the Rings: The Two Towers
# 	->The Lord of the Rings: The Return of the King
# 	->Letters from Iwo Jima
# 	->Infernal Affairs
# The Artist
# 	->Me and Earl and the Dying Girl
# 	->Three Billboards Outside Ebbing, Missouri
# 	->50/50
# 	->Silver Linings Playbook
# 	->The Broken Circle Breakdown
# King Kong
# 	->The Invisible Man
# 	->Jurassic Park
# ...
# 	->The Right Stuff
# 	->The Fly
# 	->Pink Floyd: The Wall
# Star Trek II: The Wrath of Khan
# 	->Star Trek
# 	->Aliens
# 	->The Road Warrior
# 	->Jurassic Park
# 	->Iron Man
# Malcolm X
# 	->Tombstone
# 	->Hacksaw Ridge
# 	->Schindler's List
# 	->Glory
# 	->Hotel Rwanda
# The Great Beauty
# 	->True Grit
# 	->Lion
# 	->The Fault in Our Stars
# 	->The Girl with the Dragon Tattoo
# 	->Hacksaw Ridge
# Lucky Number Slevin
# 	->No Country for Old Men
# 	->Nine Queens
# 	->Road to Perdition
# 	->Eastern Promises
# 	->The Butterfly Effect
# Billy Elliot
# 	->The Chorus
# 	->Lagaan: Once Upon a Time in India
# 	->The Butterfly Effect
# 	->Into the Wild
# 	->Ray
# Miller's Crossing
# 	->Barton Fink
# 	->Fargo
# 	->Carlito's Way
# 	->No Country for Old Men
# 	->Hell or High Water
# The Wind Rises
# 	->Hacksaw Ridge
# 	->The Intouchables
# 	->Into the Wild
# 	->Spotlight
# 	->Lion
# Paprika
# 	->Millennium Actress
# 	->Tokyo Godfathers
# 	->The Fall
# 	->Let the Right One In
# 	->Waking Life
# Run Lola Run
# 	->The Bourne Supremacy
# 	->Ghost in the Shell
# 	->The Bourne Identity
# 	->Lock, Stock and Two Smoking Barrels
# 	->Kill Bill: Vol. 2
# Ray
# 	->Control
# 	->Into the Wild
# 	->The Pianist
# 	->Walk the Line
# 	->The Chorus
# The Verdict
# 	->Pink Floyd: The Wall
# 	->Crimes and Misdemeanors
# 	->The Fly
# 	->Into the Wild
# 	->Stand by Me
# Happiness
# 	->Groundhog Day
# 	->The Muppet Christmas Carol
# 	->Rushmore
# 	->Naked
# 	->Underground
# This Is England
# 	->Dancer in the Dark
# 	->No Country for Old Men
# 	->A Prophet
# 	->Inside Man
# 	->In Bruges
# Kubo and the Two Strings
# 	->Mad Max: Fury Road
# 	->Spider-Man: Into the Spider-Verse
# 	->The Lego Movie
# 	->Big Hero 6
# 	->End of Watch
# The Longest Day
# 	->Dunkirk
# 	->Children of Men
# 	->Inherit the Wind
# 	->A Man for All Seasons
# 	->United 93
# The Quiet Man
# 	->The Searchers
# 	->Sabrina
# 	->Miracle on 34th Street
# 	->Good Bye Lenin!
# 	->Stagecoach
# The Dirty Dozen
# 	->The Wild Bunch
# 	->The Magnificent Seven
# 	->Kingsman: The Secret Service
# 	->Iron Man
# 	->Mad Max: Fury Road
# Short Cuts
# 	->Groundhog Day
# 	->The Muppet Christmas Carol
# 	->Secrets & Lies
# 	->The Big Lebowski
# 	->Underground
# Fantasia
# 	->Snow White and the Seven Dwarfs
# 	->It's a Wonderful Life
# 	->Stardust
# 	->WALL·E
# 	->Harry Potter and the Goblet of Fire
# Badlands
# 	->Enter the Dragon
# 	->The French Connection
# 	->Batman Begins
# 	->Paper Moon
# 	->Heat
# The Little Prince
# 	->Interstellar
# 	->Song of the Sea
# 	->True Grit
# 	->Hell or High Water
# 	->Into the Wild
# Finding Neverland
# 	->Into the Wild
# 	->Let's Go! India
# 	->The Sea Inside
# 	->Frost/Nixon
# 	->The Blind Side
# Happy Together
# 	->In the Mood for Love
# 	->Chungking Express
# 	->Farewell My Concubine
# 	->True Romance
# 	->The Fault in Our Stars
# Me and Earl and the Dying Girl
# 	->The Artist
# 	->50/50
# 	->A Man Called Ove
# 	->The Broken Circle Breakdown
# 	->Silver Linings Playbook
# Zulu
# 	->The Bridge on the River Kwai
# 	->Land of Mine
# 	->Inherit the Wind
# 	->A Man for All Seasons
# 	->The Great Escape
# Fantastic Planet
# 	->WALL·E
# 	->Children of Men
# 	->Alien
# 	->Iron Man
# 	->Stalker
# The African Queen
# 	->Sabrina
# 	->The Treasure of the Sierra Madre
# 	->The Asphalt Jungle
# 	->My Name Is Khan
# 	->The Bridge on the River Kwai
# Porco Rosso
# 	->Toy Story 2
# 	->Ponyo
# 	->Aladdin
# 	->Toy Story
# 	->Mulan
# Beasts of No Nation
# 	->Jojo Rabbit
# 	->1917
# 	->Tangerines
# 	->Land of Mine
# 	->The Girl with the Dragon Tattoo
# Waking Life
# 	->Millennium Actress
# 	->Before Sunset
# 	->The Fall
# 	->Pan's Labyrinth
# 	->Paprika
# A Man for All Seasons
# 	->Inherit the Wind
# 	->Hacksaw Ridge
# 	->Frost/Nixon
# 	->12 Years a Slave
# 	->The King's Speech
# Cape Fear
# 	->In the Heat of the Night
# 	->What Ever Happened to Baby Jane?
# 	->The Butterfly Effect
# 	->To Kill a Mockingbird
# 	->Persona
# When Marnie Was There
# 	->The Breadwinner
# 	->The Tale of The Princess Kaguya
# 	->Wolf Children
# 	->Your Name.
# 	->Wonder
# Nebraska
# 	->The Fault in Our Stars
# 	->Hacksaw Ridge
# 	->The Girl with the Dragon Tattoo
# 	->Hell or High Water
# 	->Dawn of the Planet of the Apes
# Good Bye Lenin!
# 	->500 Days of Summer
# 	->Lagaan: Once Upon a Time in India
# 	->Kal Ho Naa Ho
# 	->Slumdog Millionaire
# 	->No Man's Land
# The Double Life of Véronique
# 	->Three Colors: Red
# 	->Three Colors: Blue
# 	->Pink Floyd: The Wall
# 	->Underground
# 	->Groundhog Day
# Black Book
# 	->The Lives of Others
# 	->The Butterfly Effect
# 	->Tae Guk Gi: The Brotherhood of War
# 	->No Country for Old Men
# 	->Eastern Promises
# The Salesman
# 	->A Separation
# 	->Joker
# 	->Gone Girl
# 	->About Elly
# 	->Hell or High Water
# Invasion of the Body Snatchers
# 	->King Kong
# 	->Children of Men
# 	->Frankenstein
# 	->Into the Wild
# 	->The Fly
# The Motorcycle Diaries
# 	->Into the Wild
# 	->The Last King of Scotland
# 	->Almost Famous
# 	->The Fall
# 	->Hero
# Wait Until Dark
# 	->First Blood
# 	->In the Heat of the Night
# 	->Psycho
# 	->The Butterfly Effect
# 	->Persona
# Night on Earth
# 	->Underground
# 	->Groundhog Day
# 	->Secrets & Lies
# 	->Jojo Rabbit
# 	->After Hours
# The Broken Circle Breakdown
# 	->A Star Is Born
# 	->Gully Boy
# 	->The Fault in Our Stars
# 	->Her
# 	->Me and Earl and the Dying Girl
# Black Narcissus
# 	->Out of the Past
# 	->Mildred Pierce
# 	->Miracle on 34th Street
# 	->Rope
# 	->Notorious
# Evil
# 	->Lagaan: Once Upon a Time in India
# 	->Into the Wild
# 	->Let's Go! India
# 	->Match Point
# 	->The Butterfly Effect
# Frost/Nixon
# 	->Into the Wild
# 	->Hotel Rwanda
# 	->The Last King of Scotland
# 	->Downfall
# 	->A Beautiful Mind
# Taste of Cherry
# 	->Underground
# 	->Saving Private Ryan
# 	->L.A. Confidential
# 	->True Romance
# 	->Glengarry Glen Ross
# Hedwig and the Angry Inch
# 	->The Chorus
# 	->Little Miss Sunshine
# 	->Lagaan: Once Upon a Time in India
# 	->Billy Elliot
# 	->3 Idiots
# Joint Security Area
# 	->Oldboy
# 	->The Butterfly Effect
# 	->The Bourne Identity
# 	->District 9
# 	->Children of Men
# Down by Law
# 	->After Hours
# 	->Three Billboards Outside Ebbing, Missouri
# 	->Life Is Beautiful
# 	->In Bruges
# 	->The King of Comedy
# Adam's Apples
# 	->In Bruges
# 	->Dancer in the Dark
# 	->No Country for Old Men
# 	->Mother
# 	->Almost Famous
# The Triplets of Belleville
# 	->Shrek
# 	->Ponyo
# 	->Ratatouille
# 	->Finding Nemo
# 	->The Girl Who Leapt Through Time
# After the Wedding
# 	->The Butterfly Effect
# 	->Adam's Apples
# 	->Lagaan: Once Upon a Time in India
# 	->Into the Wild
# 	->Kal Ho Naa Ho
# The Experiment
# 	->The Butterfly Effect
# 	->Match Point
# 	->The White Ribbon
# 	->No Country for Old Men
# 	->Lucky Number Slevin
# The Girl Who Leapt Through Time
# 	->Shrek
# 	->Tokyo Godfathers
# 	->Ratatouille
# 	->Finding Nemo
# 	->Ponyo
# Jules and Jim
# 	->The Graduate
# 	->The Broken Circle Breakdown
# 	->The Fault in Our Stars
# 	->The Last Picture Show
# 	->The Umbrellas of Cherbourg
# The Caine Mutiny
# 	->The Bridge on the River Kwai
# 	->The African Queen
# 	->Stalag 17
# 	->Into the Wild
# 	->Casablanca
# In America
# 	->Into the Wild
# 	->Blood Diamond
# 	->Control
# 	->Lagaan: Once Upon a Time in India
# 	->The Butterfly Effect
# The Breadwinner
# 	->When Marnie Was There
# 	->The Tale of The Princess Kaguya
# 	->Wolf Children
# 	->Song of the Sea
# 	->The Wind Rises
# The Magdalene Sisters
# 	->Into the Wild
# 	->The Butterfly Effect
# 	->Lagaan: Once Upon a Time in India
# 	->No Country for Old Men
# 	->Children of Men
# The Purple Rose of Cairo
# 	->Midnight in Paris
# 	->Hannah and Her Sisters
# 	->Annie Hall
# 	->Crimes and Misdemeanors
# 	->Ghostbusters
# Love and Death
# 	->Annie Hall
# 	->Manhattan
# 	->Crimes and Misdemeanors
# 	->The Man Who Would Be King
# 	->No Man's Land
# My Life as a Zucchini
# 	->Three Billboards Outside Ebbing, Missouri
# 	->The Intouchables
# 	->Toy Story 3
# 	->Jojo Rabbit
# 	->Sing Street
# The Past
# 	->The Girl with the Dragon Tattoo
# 	->Gone Girl
# 	->Wind River
# 	->The Best Offer
# 	->Searching
# The Muppet Christmas Carol
# 	->The Sandlot
# 	->Miracle on 34th Street
# 	->Groundhog Day
# 	->Moonrise Kingdom
# 	->Children of Heaven
# The Edge of Heaven
# 	->Head-On
# 	->The Butterfly Effect
# 	->No Country for Old Men
# 	->In Bruges
# 	->Into the Wild
# Harry Potter and the Sorcerer's Stone
# 	->Harry Potter and the Goblet of Fire
# 	->Harry Potter and the Prisoner of Azkaban
# 	->Harry Potter and the Deathly Hallows: Part 1
# 	->Harry Potter and the Deathly Hallows: Part 2
# 	->Stardust
# Once Upon a Time in Hollywood
# 	->The Wolf of Wall Street
# 	->Django Unchained
# 	->The Big Short
# 	->The Intouchables
# 	->Jojo Rabbit
# American Psycho
# 	->3:10 to Yuma
# 	->The Dark Knight
# 	->Batman Begins
# 	->No Country for Old Men
# 	->Dancer in the Dark
# Moana
# 	->Aladdin
# 	->Klaus
# 	->Isle of Dogs
# 	->Toy Story 4
# 	->Toy Story 3
# Office Space
# 	->Underground
# 	->Mulan
# 	->The Iron Giant
# 	->Groundhog Day
# 	->The Big Lebowski
# Deadpool 2
# 	->Deadpool
# 	->Kingsman: The Secret Service
# 	->Hunt for the Wilderpeople
# 	->Guardians of the Galaxy Vol. 2
# 	->The Gentlemen
# The Birds
# 	->Psycho
# 	->What Ever Happened to Baby Jane?
# 	->Rope
# 	->In the Heat of the Night
# 	->Rosemary's Baby
# Moneyball
# 	->The Big Short
# 	->Hacksaw Ridge
# 	->Ford v Ferrari
# 	->The Intouchables
# 	->Lion
# My Cousin Vinny
# 	->The Big Lebowski
# 	->In Bruges
# 	->Goodfellas
# 	->Casino
# 	->The Gentlemen
# Saw
# 	->The Others
# 	->The Bourne Supremacy
# 	->The Bourne Identity
# 	->The Bourne Ultimatum
# 	->Psycho
# Superbad
# 	->Shrek
# 	->In Bruges
# 	->Finding Nemo
# 	->Almost Famous
# 	->Kal Ho Naa Ho
# Sicario
# 	->Blade Runner 2049
# 	->The Girl with the Dragon Tattoo
# 	->Elite Squad 2: The Enemy Within
# 	->I Saw the Devil
# 	->Prisoners
# The Fifth Element
# 	->Jurassic Park
# 	->Die Hard with a Vengeance
# 	->Iron Man
# 	->The Iron Giant
# 	->The Matrix
# Inside Man
# 	->The Girl with the Dragon Tattoo
# 	->Zodiac
# 	->Man on Fire
# 	->Mother
# 	->A Very Long Engagement
# 300
# 	->Man on Fire
# 	->Watchmen
# 	->Children of Men
# 	->V for Vendetta
# 	->Hero
# Stardust
# 	->Harry Potter and the Goblet of Fire
# 	->WALL·E
# 	->Harry Potter and the Sorcerer's Stone
# 	->Harry Potter and the Prisoner of Azkaban
# 	->Howl's Moving Castle
# Guardians of the Galaxy Vol. 2
# 	->Guardians of the Galaxy
# 	->Kingsman: The Secret Service
# 	->The Lego Movie
# 	->Star Trek Into Darkness
# 	->The Iron Giant
# Watchmen
# 	->300
# 	->Children of Men
# 	->The Bourne Identity
# 	->Oldboy
# 	->Man on Fire
# Hell or High Water
# 	->True Grit
# 	->Shoplifters
# 	->Joker
# 	->Nightcrawler
# 	->Once Upon a Time in Anatolia
# Kick-Ass
# 	->Kingsman: The Secret Service
# 	->Gangs of Wasseypur
# 	->The Gentlemen
# 	->Three Billboards Outside Ebbing, Missouri
# 	->End of Watch
# Star Wars: Episode III - Revenge of the Sith
# 	->Star Wars
# 	->Big Fish
# 	->The Incredibles
# 	->Avatar
# 	->The Fall
# A Star Is Born
# 	->The Broken Circle Breakdown
# 	->Silver Linings Playbook
# 	->Gully Boy
# 	->The Fault in Our Stars
# 	->Her
# Lethal Weapon
# 	->Kill Bill: Vol. 2
# 	->Run Lola Run
# 	->The Raid: Redemption
# 	->First Blood
# 	->John Wick: Chapter 4
# The Blind Side
# 	->The World's Fastest Indian
# 	->Into the Wild
# 	->Remember the Titans
# 	->Lagaan: Once Upon a Time in India
# 	->Crash
# Kung Fu Panda
# 	->The Incredibles
# 	->WALL·E
# 	->Ratatouille
# 	->Iron Man
# 	->The Iron Giant
# Gone Baby Gone
# 	->Zodiac
# 	->Inside Man
# 	->Mother
# 	->Lucky Number Slevin
# 	->No Country for Old Men
# The Royal Tenenbaums
# 	->The Chorus
# 	->In Bruges
# 	->Fantastic Mr. Fox
# 	->No Man's Land
# 	->Kal Ho Naa Ho
# Minority Report
# 	->Inside Man
# 	->In Bruges
# 	->Man on Fire
# 	->Catch Me If You Can
# 	->Zodiac
# RoboCop
# 	->Aliens
# 	->The Killer
# 	->Star Trek II: The Wrath of Khan
# 	->Children of Men
# 	->Run Lola Run
# The Thin Red Line
# 	->Saving Private Ryan
# 	->The Game
# 	->Tombstone
# 	->Land of Mine
# 	->Schindler's List
# Searching
# 	->Gone Girl
# 	->The Girl with the Dragon Tattoo
# 	->Joker
# 	->Hell or High Water
# 	->Wind River
# Despicable Me
# 	->Isle of Dogs
# 	->Toy Story 3
# 	->Toy Story 4
# 	->Zootopia
# 	->Tangled
# Mulan
# 	->Shrek
# 	->Toy Story
# 	->Toy Story 2
# 	->Aladdin
# 	->The Iron Giant
# The Butterfly Effect
# 	->Children of Men
# 	->No Country for Old Men
# 	->District 9
# 	->Crash
# 	->Eastern Promises
# After Hours
# 	->The King of Comedy
# 	->Three Billboards Outside Ebbing, Missouri
# 	->The Gentlemen
# 	->In Bruges
# 	->Down by Law
# The Raid: Redemption
# 	->The Raid 2
# 	->Kill Bill: Vol. 2
# 	->End of Watch
# 	->Gangs of Wasseypur
# 	->Kick-Ass
# Dark City
# 	->12 Monkeys
# 	->The Matrix
# 	->Terminator 2: Judgment Day
# 	->The Green Mile
# 	->The Butterfly Effect
# The Fly
# 	->Jurassic Park
# 	->Brazil
# 	->Frankenstein
# 	->After Hours
# 	->King Kong
# What We Do in the Shadows
# 	->Jojo Rabbit
# 	->Philomena
# 	->The Intouchables
# 	->Kingsman: The Secret Service
# 	->Three Billboards Outside Ebbing, Missouri
# The Skin I Live In
# 	->The Girl with the Dragon Tattoo
# 	->Wind River
# 	->Gone Girl
# 	->Talk to Her
# 	->Get Out
# Rushmore
# 	->Fantastic Mr. Fox
# 	->Moonrise Kingdom
# 	->Groundhog Day
# 	->True Romance
# 	->Life Is Beautiful
# True Grit
# 	->Hell or High Water
# 	->Ford v Ferrari
# 	->No Country for Old Men
# 	->The Martian
# 	->Joker
# The Others
# 	->Saw
# 	->The Bourne Identity
# 	->The Bourne Supremacy
# 	->The Bourne Ultimatum
# 	->Get Out
# The Mitchells vs the Machines
# 	->Ratatouille
# 	->Puss in Boots: The Last Wish
# 	->Shrek
# 	->Soul
# 	->Ponyo
# The Road Warrior
# 	->Mad Max: Fury Road
# 	->Star Trek II: The Wrath of Khan
# 	->Jurassic Park
# 	->Iron Man
# 	->Aliens
# Eastern Promises
# 	->21 Grams
# 	->Crash
# 	->No Country for Old Men
# 	->Road to Perdition
# 	->The Butterfly Effect
# Dark Waters
# 	->12 Years a Slave
# 	->Spotlight
# 	->Hacksaw Ridge
# 	->The King's Speech
# 	->Hidden Figures
# Dawn of the Planet of the Apes
# 	->Avengers: Endgame
# 	->The Dark Knight Rises
# 	->The Revenant
# 	->Spider-Man: Into the Spider-Verse
# 	->Kingsman: The Secret Service
# The Jungle Book
# 	->The Girl Who Leapt Through Time
# 	->Finding Nemo
# 	->Ratatouille
# 	->The Mitchells vs the Machines
# 	->Ponyo
# End of Watch
# 	->Spider-Man: Into the Spider-Verse
# 	->Kubo and the Two Strings
# 	->Edge of Tomorrow
# 	->Mad Max: Fury Road
# 	->Kingsman: The Secret Service
# Enter the Dragon
# 	->Badlands
# 	->The French Connection
# 	->Sicario
# 	->Le Cercle Rouge
# 	->Heat
# The Naked Gun: From the Files of Police Squad!
# 	->After Hours
# 	->The Gentlemen
# 	->In Bruges
# 	->The King of Comedy
# 	->Paper Moon
# Rebel Without a Cause
# 	->The Bridge on the River Kwai
# 	->Into the Wild
# 	->Anatomy of a Murder
# 	->The Asphalt Jungle
# 	->East of Eden
# Ponyo
# 	->Shrek
# 	->Spirited Away
# 	->Ratatouille
# 	->Howl's Moving Castle
# 	->The Triplets of Belleville
# Snow White and the Seven Dwarfs
# 	->WALL·E
# 	->Spirited Away
# 	->King Kong
# 	->Fantasia
# 	->Howl's Moving Castle
# Match Point
# 	->The Butterfly Effect
# 	->No Country for Old Men
# 	->Crash
# 	->The Lives of Others
# 	->The White Ribbon
# Die Hard with a Vengeance
# 	->The Fifth Element
# 	->Jurassic Park
# 	->First Blood
# 	->Skyfall
# 	->The Sixth Sense
# The Last King of Scotland
# 	->Downfall
# 	->Frost/Nixon
# 	->Into the Wild
# 	->Hotel Rwanda
# 	->The Motorcycle Diaries
# Philomena
# 	->The Intouchables
# 	->Pride
# 	->Lion
# 	->Three Billboards Outside Ebbing, Missouri
# 	->Hidden Figures
# The Bridges of Madison County
# 	->Unforgiven
# 	->True Romance
# 	->Rushmore
# 	->Million Dollar Baby
# 	->Gran Torino
# 50/50
# 	->Me and Earl and the Dying Girl
# 	->The Artist
# 	->Silver Linings Playbook
# 	->Flipped
# 	->The Broken Circle Breakdown
# Seven Pounds
# 	->The Pursuit of Happyness
# 	->25th Hour
# 	->The Butterfly Effect
# 	->Into the Wild
# 	->Lagaan: Once Upon a Time in India
# 21 Grams
# 	->Eastern Promises
# 	->No Country for Old Men
# 	->Crash
# 	->Road to Perdition
# 	->Nine Queens
# I Am Sam
# 	->Man on Fire
# 	->Children of Men
# 	->Coraline
# 	->The Butterfly Effect
# 	->Into the Wild
# Sabrina
# 	->Stalag 17
# 	->Sunset Blvd.
# 	->Some Like It Hot
# 	->The African Queen
# 	->The Quiet Man
# From Here to Eternity
# 	->The Bridge on the River Kwai
# 	->Vertigo
# 	->High Noon
# 	->Gone with the Wind
# 	->Casablanca
# Barton Fink
# 	->Miller's Crossing
# 	->The Big Lebowski
# 	->O Brother, Where Art Thou?
# 	->Fargo
# 	->Carlito's Way
# 25th Hour
# 	->Into the Wild
# 	->Inside Man
# 	->Children of Men
# 	->The Butterfly Effect
# 	->Lagaan: Once Upon a Time in India
# A Very Long Engagement
# 	->Inside Man
# 	->Amélie
# 	->Talk to Her
# 	->Atonement
# 	->The Secret in Their Eyes
# The Taking of Pelham One Two Three
# 	->Dirty Harry
# 	->Le Cercle Rouge
# 	->Run Lola Run
# 	->John Wick: Chapter 4
# 	->Badlands
# United 93
# 	->Children of Men
# 	->Man on Fire
# 	->Dunkirk
# 	->Black Hawk Down
# 	->Frost/Nixon
# Control
# 	->Walk the Line
# 	->Ray
# 	->Into the Wild
# 	->Frost/Nixon
# 	->The Pianist
# Eyes Without a Face
# 	->What Ever Happened to Baby Jane?
# 	->Rosemary's Baby
# 	->The Birds
# 	->Psycho
# 	->The Butterfly Effect
# Shine
# 	->Ray
# 	->The King's Speech
# 	->Into the Wild
# 	->Hacksaw Ridge
# 	->Bohemian Rhapsody
# The Invisible Man
# 	->King Kong
# 	->Frankenstein
# 	->The Bride of Frankenstein
# 	->Invasion of the Body Snatchers
# 	->Children of Men
# The Odd Couple
# 	->Charade
# 	->The Apartment
# 	->Kingsman: The Secret Service
# 	->The Graduate
# 	->Kick-Ass

# %%
lines = "{'1681335863852': {'Username': 'Prayash', 'Title': 'The Godfather', 'Rating': '9', 'Review': 'asfdafsd'}, '1681335868552': {'Username': 'Prayash', 'Title': 'Movie 2', 'Rating': '3', 'Review': 'asdfasfdasdfasdf'}, '1681335874235': {'Username': 'Prayash', 'Title': '12 Angry Men', 'Rating': '10', 'Review': 'asfasdadsasdfasdf'}}".replace("'", "\"")

def get_recs(lines):
    lines = json.loads(lines)
    user_movies = pd.DataFrame(lines).T
    movie_names = user_movies[user_movies["Rating"].astype(float) >= 8]["Title"]  # get the names of the highly rated movies
    movie_index = np.flatnonzero(features_df.index.isin(movie_names))  # get the indices of highly rated movies
    rec_movies = pd.DataFrame([output_links[movie_index].flatten(), output_probs[movie_index].flatten()]).T
    rec_movies.sort_values(1, ascending=False, inplace=True)
    similar_films = list(np.unique(features_df.iloc[rec_movies[0][:3]].index))  # get names
    return similar_films
    
get_recs(lines)
# Out:
# ['Apocalypse Now', 'Serpico', 'The Godfather Part II']

# %%
pd.DataFrame(torch.concat([output_links.T, output_probs.T]).detach().numpy().T, index=features_df.index).to_csv("SimilarityMatrices.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26284\174621646.py in <module>
# ----> 1 pd.DataFrame(torch.concat([output_links.T, output_probs.T]).detach().numpy().T, index=features_df.index).to_csv("SimilarityMatrices.csv")
#
# NameError: name 'output_links' is not defined

# %%
df = pd.read_csv("SimilarityIndices.csv")
movie_list = df["title"]
links = df[["0", "1", "2", "3", "4"]].values
df = pd.read_csv("SimilarityProbs.csv").values
movie_list
# Out:
# 0                           The Shawshank Redemption
# 1                                      The Godfather
# 2                                    The Dark Knight
# 3                                   Schindler's List
# 4      The Lord of the Rings: The Return of the King
#                            ...
# 833                                          Control
# 834                              Eyes Without a Face
# 835                                            Shine
# 836                                The Invisible Man
# 837                                   The Odd Couple
# Name: title, Length: 838, dtype: object

# %%
input_movies = ["The Treasure of the Sierra Madre", "Dirty Harry", "The Fugitive", "The Godfather"]
sim_mat = pd.read_csv("FullMatrix.csv").set_index("title")

# %%
lines = "{'1681335863852': {'Username': 'Prayash', 'Title': 'The Godfather', 'Rating': '9', 'Review': 'asfdafsd'}, '1681335868552': {'Username': 'Prayash', 'Title': 'The Treasure of the Sierra Madre', 'Rating': '10', 'Review': 'asdfasfdasdfasdf'}, '1681335874235': {'Username': 'Prayash', 'Title': 'The Fugitive', 'Rating': '10', 'Review': 'asfasdadsasdfasdf'}}".replace("'", "\"")

def get_recs(lines, genre="Crime"):
    lines = json.loads(lines)
    user_movies = pd.DataFrame(lines).T
    sim_mat = pd.read_csv("FullMatrix.csv").set_index("title")
    movie_names = user_movies[user_movies["Rating"].astype(float) >= 8][
        "Title"]  # get the names of the highly rated movies
    movie_names = [movie for movie in movie_names if movie in sim_mat.index]
    rec_movies = []

    # For first recommendation, take most similar to all inputs by  mean
    # For now, random from top len(great_movies)
    indices = np.argsort(np.mean(sim_mat[movie_names].values, axis=1))[-len(movie_names):]
    poss_movies = sim_mat.index[indices]
    rec_movies.append(poss_movies[np.random.randint(len(poss_movies))])

    # For the second recommendation, take random movie in five most similar to each one they like
    poss_movies = [film_name for i in sim_mat[movie_names].T.values for film_name in sim_mat.index[np.argsort(i)[-5:]]]
    poss_movies = [movie for movie in poss_movies if movie not in movie_names]
    rec_movies.append(poss_movies[np.random.randint(len(poss_movies))])

    # For third recommendation, take highest 2 single similarity to each film given genre
    genre_titles = movies_df[[genre in movie_genres for movie_genres in movies_df["genre"]]]["title"]
    genre_titles = np.unique([title for title in genre_titles if title in sim_mat] + movie_names)
    genre_mat = sim_mat[genre_titles].T[genre_titles]
    indices = np.argsort(genre_mat[movie_names].values, axis=0)[-2:].T
    poss_movies = [film_name for i, s in enumerate(indices) for film_name in genre_mat[movie_names[i]].iloc[s].index]
    poss_movies = [movie for movie in poss_movies if movie not in movie_names]
    rec_movies.append(poss_movies[np.random.randint(len(poss_movies))])

    return rec_movies
    
get_recs(lines)
# Out:
# ['Children of Men', 'The Maltese Falcon', 'Serpico']
